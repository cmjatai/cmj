# %%
from cmj.loa import models
from cmj.utils import Manutencao, run_sql
from django.conf import settings
from django.db.models import Q, F
from django.db.models.aggregates import Sum
from decimal import Decimal
import fitz
import re
m = Manutencao()
m.desativa_auto_now()
m.desativa_signals()

# %%
loa = models.Loa.objects.get(pk=2020)

# %%
(models.Despesa.objects.filter(loa=loa).delete(), 
models.Orgao.objects.filter(loa=loa).delete(),
models.UnidadeOrcamentaria.objects.filter(loa=loa).delete(),
models.Funcao.objects.filter(loa=loa).delete(),
models.SubFuncao.objects.filter(loa=loa).delete(),
models.Programa.objects.filter(loa=loa).delete(),
models.Acao.objects.filter(loa=loa).delete(),
models.Natureza.objects.filter(loa=loa).delete(),
models.EmendaLoaRegistroContabil.objects.filter(emendaloa__loa=loa).delete())
# Out:
# ((0, {}),
#  (0, {}),
#  (0, {}),
#  (0, {}),
#  (0, {}),
#  (0, {}),
#  (0, {}),
#  (0, {}),
#  (0, {'loa.EmendaLoaRegistroContabil': 0}))

# %%
autografo = NormaJuridica.objects.get(pk=8483)
# Out:
# <Loa: LOA 2020 - >

# %%
dfile = fitz.open(autografo.texto_integral.path)
#dfile = fitz.open('/home/leandro/Downloads/anexo_materia.pdf')

# %%
def load_pages_with(page_mask=''):
    rtext = ''
    for np in range(len(dfile)):
        page = dfile.load_page(np)
        text = page.get_text("text")

        if page_mask not in text:
            continue

        rtext += text
    while '  ' in rtext:
        rtext = rtext.replace('  ', ' ')
    while ' \n' in rtext:
        rtext = rtext.replace(' \n', '\n')
    while '\n\n' in rtext:
        rtext = rtext.replace('\n\n', '\n')
    return rtext

# %%
text_global = load_pages_with(page_mask='Quadro de Detalhamento da Despesa\nEXERCÍCIO DE 2020\n')

# %%
len(text_global), text_global[0:1000]
# Out:
# (49383,
#  'ESTADO DE GOIÁS\nMUNICÍPIO DE JATAI\nQuadro de Detalhamento da Despesa\nEXERCÍCIO DE 2020\nRUA ITARUMA, 355 - S. SANTA MARIA\n1\nPÁGINA\nUNIDADE ORÇAMENTÁRIA\nÓRGÃO\nCÓDIGO\nCÓDIGO\nAPLICAÇÃO PROGRAMADA\nCÓDIGOS\nDETALHADA\nAPLICADO\nNATUREZA DA\nCLASSIFICAÇÃO ORÇAMENTÁRIA\nVALORES\nDESPESA\nTOTAL\nCAMARA MUNICIPAL DE JATAI\nCAMARA MUNICIPAL\n01\n01\nOBRAS,INSTAL.EQUIP.CAMARA MUNICIPAL\n01.031.0139.1.001\n4.4.90.51.00\n218.196,31\n4.4.90.52.00\n603.360,24\n821.556,55\nMANUT.ATIV.DA CAMARA MUNICIPAL\n01.031.0139.2.001\n3.1.90.04.00\n9.486,80\n3.1.90.11.00\n11.185.818,60\n3.1.90.16.00\n18.973,59\n3.1.90.92.00\n948,68\n3.3.90.14.00\n137.558,55\n3.3.90.30.00\n512.287,00\n3.3.90.33.00\n6.640,76\n3.3.90.34.00\n151.788,74\n3.3.90.35.00\n47.433,98\n3.3.90.36.00\n85.381,17\n3.3.90.37.00\n9.486,80\n3.3.90.39.00\n569.207,77\n3.3.90.40.00\n100.000,00\n3.3.90.92.00\n948,68\n12.835.961,12\nENC.PREV.C/O REGIME GERAL DE PREVIDÊNCIA\n01.271.2839.9.061\n3.1.90.13.00\n958.267,07\n3.1.90.54.00\n1.897,36\n3.1.90.56.00\n1.897,36\n3.1.90.58.00\n474,34\n3.1.90.92.00\n474,34\n963.01')

# %%
aplicacoes = []
for m in re.finditer(r'(.+)\n(\d{2}\.\d{3}\.\d{4}\.\d\.\d{3})', text_global):
    aplicacoes.append([m.start(), m.end(), list(m.groups())])
aplicacoes.append([len(text_global),len(text_global),None])
for i in range(len(aplicacoes)-1):
    aplic = aplicacoes[i]
    x1 = aplicacoes[i][1]
    x2 = aplicacoes[i+1][0]

    natdespesas = []

    for n in re.finditer(r'(\d{1,2}\.\d{1,2}\.\d{2}\.\d{2}\.\d{2})\n(\d{0,3}(?:\.\d{3})*,\d{2})', text_global[x1:x2]):
        natdespesas.append(list(n.groups()))

    aplic.append(natdespesas)
    
aplicacoes.pop()
aplicacoes = list(map(lambda x: (x[2][1], x[2][0], x[0], x[1], tuple(x[3])), aplicacoes))

# %%
aplicacoes
# Out:
# [('01.031.0139.1.001',
#   'OBRAS,INSTAL.EQUIP.CAMARA MUNICIPAL',
#   329,
#   382,
#   (['4.4.90.51.00', '218.196,31'], ['4.4.90.52.00', '603.360,24'])),
#  ('01.031.0139.2.001',
#   'MANUT.ATIV.DA CAMARA MUNICIPAL',
#   442,
#   490,
#   (['3.1.90.04.00', '9.486,80'],
#    ['3.1.90.11.00', '11.185.818,60'],
#    ['3.1.90.16.00', '18.973,59'],
#    ['3.1.90.92.00', '948,68'],
#    ['3.3.90.14.00', '137.558,55'],
#    ['3.3.90.30.00', '512.287,00'],
#    ['3.3.90.33.00', '6.640,76'],
#    ['3.3.90.34.00', '151.788,74'],
#    ['3.3.90.35.00', '47.433,98'],
#    ['3.3.90.36.00', '85.381,17'],
#    ['3.3.90.37.00', '9.486,80'],
#    ['3.3.90.39.00', '569.207,77'],
#    ['3.3.90.40.00', '100.000,00'],
#    ['3.3.90.92.00', '948,68'])),
#  ('01.271.2839.9.061',
#   'ENC.PREV.C/O REGIME GERAL DE PREVIDÊNCIA',
#   827,
#   885,
#   (['3.1.90.13.00', '958.267,07'],
#    ['3.1.90.54.00', '1.897,36'],
#    ['3.1.90.56.00', '1.897,36'],
#    ['3.1.90.58.00', '474,34'],
#    ['3.1.90.92.00', '474,34'])),
#  ('01.272.2839.9.001',
#   'ENC.PREV. C/O REGIME PRÓPRIO DE PREVIDÊNCIA',
#   1005,
#   1066,
#   (['3.1.90.01.00', '2.371,70'],
#    ['3.1.90.03.00', '2.371,70'],
#    ['3.1.91.13.00', '284.603,89'],
#    ['3.1.91.92.00', '1.897,36'],
#    ['3.3.90.05.00', '474,34'],
#    ['3.3.91.97.00', '1.423,02'])),
#  ('01.845.2839.9.002',
#   'TRANSFERÊNCIAS A INSTITUIÇÕES PRIVADAS',
#   1628,
#   1684,
#   (['3.3.50.41.00', '9.486,80'],)),
#  ('01.846.2839.9.003',
#   'OUTROS ENCARGOS ESPECIAIS DA CÂMARA',
#   1716,
#   1769,
#   (['3.1.90.91.00', '18.973,59'],
#    ['3.1.90.94.00', '47.433,98'],
#    ['3.2.90.21.00', '4.743,40'],
#    ['3.2.90.22.00', '948,68'],
#    ['3.2.90.91.00', '948,68'],
#    ['3.2.90.92.00', '948,68'],
#    ['3.3.90.91.00', '2.846,04'])),
#  ('04.122.0439.1.029',
#   'BENS MÓVEIS P/O GABINETE DO PREFEITO',
#   2425,
#   2479,
#   (['4.4.90.52.00', '50.000,00'],)),
#  ('04.122.0439.2.002',
#   'MANUT.ATIV.SEC.EXECUTIVA GABINETE DO PREFEITO',
#   2513,
#   2576,
#   (['3.1.90.11.00', '1.300.000,00'],
#    ['3.3.90.14.00', '45.000,00'],
#    ['3.3.90.30.00', '30.000,00'],
#    ['3.3.90.33.00', '3.000,00'],
#    ['3.3.90.34.00', '10.000,00'],
#    ['3.3.90.36.00', '4.000,00'],
#    ['3.3.90.39.00', '100.000,00'],
#    ['3.3.90.92.00', '500,00'])),
#  ('04.122.0439.2.003',
#   'MANUT.ATIVIDADES DA PROCURADORIA GERAL',
#   2773,
#   2829,
#   (['3.1.90.11.00', '1.202.000,00'],
#    ['3.3.90.14.00', '4.743,40'],
#    ['3.3.90.30.00', '9.486,80'],
#    ['3.3.90.36.00', '4.743,40'],
#    ['3.3.90.39.00', '9.486,80'],
#    ['3.3.90.92.00', '948,68'])),
#  ('04.122.0439.2.004',
#   'DIVULG.PROP.PUBLIC.OFICIAIS E ATOS ADM',
#   2977,
#   3033,
#   (['3.3.90.30.00', '2.000,00'],
#    ['3.3.90.36.00', '2.000,00'],
#    ['3.3.90.39.00', '800.000,00'],
#    ['3.3.90.92.00', '500,00'])),
#  ('04.122.0439.2.005',
#   'MANUT.ATIV.DA OUVIDORIA GERAL DO MUNICÍPIO',
#   3133,
#   3193,
#   (['3.1.90.04.00', '500,00'],
#    ['3.1.90.11.00', '102.000,00'],
#    ['3.3.90.14.00', '1.000,00'],
#    ['3.3.90.30.00', '4.000,00'],
#    ['3.3.90.35.00', '1.000,00'],
#    ['3.3.90.36.00', '4.000,00'],
#    ['3.3.90.39.00', '4.000,00'],
#    ['3.3.90.92.00', '200,00'])),
#  ('04.122.0439.2.008',
#   'FESTIVIDADES, RECEPÇÕES E HOMENAGENS',
#   3804,
#   3858,
#   (['3.3.90.30.00', '75.000,00'],
#    ['3.3.90.36.00', '5.000,00'],
#    ['3.3.90.39.00', '200.000,00'])),
#  ('04.122.0839.2.046',
#   'MANUT.DEPART.PROGRAMAS E PROJETOS',
#   3939,
#   3990,
#   (['3.3.90.92.00', '948,68'],)),
#  ('04.124.0439.2.006',
#   'MANUT.ATIV.DA CONTROLADORIA GERAL DO MUNICÍPIO',
#   4018,
#   4082,
#   (['3.1.90.04.00', '400,00'],
#    ['3.1.90.11.00', '302.000,00'],
#    ['3.3.90.14.00', '1.500,00'],
#    ['3.3.90.30.00', '5.000,00'],
#    ['3.3.90.34.00', '3.000,00'],
#    ['3.3.90.36.00', '2.000,00'],
#    ['3.3.90.39.00', '2.000,00'],
#    ['3.3.90.92.00', '200,00'])),
#  ('04.846.2839.9.004',
#   'ENCARGOS ESP. DO GABINETE DO PREFEITO',
#   4268,
#   4323,
#   (['3.1.90.91.00', '10.000,00'], ['3.1.90.94.00', '20.000,00'])),
#  ('16.244.1639.1.002',
#   'OBRAS,INSTAL.EQUIP.SUPERINTEDÊNCIA DE HABITAÇÃO',
#   4380,
#   4445,
#   (['4.4.90.51.00', '164.735,92'],
#    ['4.4.90.52.00', '18.973,59'],
#    ['4.4.90.61.00', '9.486,80'])),
#  ('16.244.1639.2.010',
#   'MANUT.ATIV.SUPERINTENDÊNCIA DE HABITAÇÃO',
#   4526,
#   4584,
#   (['3.1.90.04.00', '300,00'],
#    ['3.1.90.11.00', '262.000,00'],
#    ['3.3.90.14.00', '1.500,00'],
#    ['3.3.90.30.00', '10.000,00'],
#    ['3.3.90.36.00', '5.000,00'],
#    ['3.3.90.39.00', '220.000,00'],
#    ['3.3.90.92.00', '500,00'])),
#  ('16.846.2839.9.005',
#   'ENCARGOS ESPECIAIS DA SUPER. DE HABITAÇÃO',
#   5174,
#   5233,
#   (['3.1.90.94.00', '8.000,00'], ['3.3.90.32.00', '5.000,00'])),
#  ('02.061.0239.1.031',
#   'BENS MÓVEIS P/O PODER JUDICIÁRIO E ELEITORAL',
#   5741,
#   5803,
#   (['4.4.90.52.00', '1.000,00'],)),
#  ('02.061.0239.2.011',
#   'ENCARGOS C/O PODER JUDICIÁRIO ELEITORAL',
#   5835,
#   5892,
#   (['3.3.90.30.00', '2.000,00'],
#    ['3.3.90.36.00', '2.000,00'],
#    ['3.3.90.39.00', '2.000,00'])),
#  ('04.122.0439.1.045',
#   'OBRAS,INSTAL.EQUIP.PRÉDIOS PÚBLICOS',
#   5968,
#   6021,
#   (['4.4.90.51.00', '1.576.532,65'],
#    ['4.4.90.52.00', '22.332,84'],
#    ['4.4.90.61.00', '336.640,76'])),
#  ('04.122.0439.2.012',
#   'MANUT.ATIV.DIVISÃO DE SERVIÇOS ADMINISTRATIVOS',
#   6108,
#   6172,
#   (['3.1.90.04.00', '500,00'],
#    ['3.1.90.11.00', '5.980.000,00'],
#    ['3.3.90.14.00', '35.000,00'],
#    ['3.3.90.30.00', '800.000,00'],
#    ['3.3.90.33.00', '1.000,00'],
#    ['3.3.90.34.00', '5.000,00'],
#    ['3.3.90.36.00', '150.000,00'],
#    ['3.3.90.39.00', '4.150.000,00'],
#    ['3.3.90.40.00', '400.000,00'],
#    ['3.3.90.92.00', '500,00'],
#    ['4.4.90.52.00', '40.000,00'])),
#  ('04.122.0439.2.013',
#   'MANUT.ATIV.DA DIVISÃO DE RECURSOS HUMANOS',
#   6441,
#   6500,
#   (['3.1.90.04.00', '500,00'],
#    ['3.1.90.11.00', '1.000,00'],
#    ['3.3.90.14.00', '1.500,00'],
#    ['3.3.90.30.00', '2.500,00'],
#    ['3.3.90.35.00', '5.000,00'],
#    ['3.3.90.36.00', '4.000,00'],
#    ['3.3.90.39.00', '3.000,00'],
#    ['3.3.90.92.00', '400,00'])),
#  ('04.122.0439.2.014',
#   'MANUT. DE PRÉDIOS PÚBLICOS DIVERSOS',
#   7122,
#   7175,
#   (['3.3.90.30.00', '420.000,00'],
#    ['3.3.90.36.00', '4.000,00'],
#    ['3.3.90.39.00', '525.000,00'],
#    ['3.3.90.92.00', '500,00'],
#    ['4.4.90.52.00', '40.000,00'])),
#  ('04.122.0439.2.017',
#   'MANUT.ATIV.DE DIVISÃO DE PLANEJAMENTO',
#   7300,
#   7355,
#   (['3.1.90.11.00', '1.000,00'],
#    ['3.3.90.14.00', '1.000,00'],
#    ['3.3.90.30.00', '40.000,00'],
#    ['3.3.90.36.00', '12.000,00'],
#    ['3.3.90.39.00', '16.000,00'])),
#  ('04.845.2839.9.008',
#   'TRANSFERÊNCIAS A INSTITUIÇÕES PRIVADAS',
#   7479,
#   7535,
#   (['3.3.50.43.00', '47.433,98'], ['3.3.60.41.00', '20.000,00'])),
#  ('04.846.2839.9.010',
#   'OUTROS ENCARGOS DA SEC.DE ADMINISTRAÇÃO',
#   7592,
#   7649,
#   (['3.1.90.91.00', '10.000,00'],
#    ['3.1.90.94.00', '60.000,00'],
#    ['3.3.90.10.00', '5.000,00'],
#    ['3.3.90.32.00', '5.000,00'])),
#  ('09.271.0939.9.006',
#   'ENC. PREV. C/O REGIME GERAL DE PREVIDÊNCIA',
#   7750,
#   7810,
#   (['3.1.90.13.00', '3.400.000,00'], ['3.1.90.92.00', '1.000,00'])),
#  ('09.272.0939.9.007',
#   'ENC.PREV.C/O REGIME PRÓPRIO DE PREVIDÊNCIA',
#   7872,
#   7932,
#   (['3.1.90.03.00', '120.000,00'],
#    ['3.1.91.13.00', '2.800.000,00'],
#    ['3.3.91.97.00', '1.650.000,00'])),
#  ('26.122.2639.1.004',
#   'OBRAS,INSTAL.EQUIP. P/O TRANSPORTE MUNICIPAL',
#   8022,
#   8084,
#   (['4.4.90.51.00', '28.460,39'], ['4.4.90.52.00', '28.460,39'])),
#  ('26.122.2639.2.016',
#   'MANUT.DIVISÃO DE VEÍCULOS, MAQUIN.E EQUIPAMENTOS',
#   8141,
#   8207,
#   (['3.1.90.04.00', '400,00'],
#    ['3.1.90.11.00', '1.000,00'],
#    ['3.3.90.14.00', '1.000,00'],
#    ['3.3.90.30.00', '3.100.000,00'],
#    ['3.3.90.36.00', '15.000,00'],
#    ['3.3.90.39.00', '600.000,00'],
#    ['3.3.90.92.00', '500,00'])),
#  ('26.846.2839.9.012',
#   'OUTROS ENCARGOS DO SETOR DE TRANSPORTES',
#   8824,
#   8881,
#   (['3.1.90.91.00', '1.500,00'], ['3.1.90.94.00', '5.000,00'])),
#  ('04.123.0439.1.034',
#   'BENS MÓVEIS P/ SECRETARIA DA FAZENDA',
#   9390,
#   9444,
#   (['4.4.90.52.00', '40.000,00'],)),
#  ('04.123.0439.2.019',
#   'MANUT.ATIV.DA SECRETARIA DA FAZENDA',
#   9478,
#   9531,
#   (['3.1.90.11.00', '3.030.000,00'],
#    ['3.3.90.14.00', '5.000,00'],
#    ['3.3.90.30.00', '1.000,00'],
#    ['3.3.90.34.00', '500,00'],
#    ['3.3.90.35.00', '4.500,00'],
#    ['3.3.90.36.00', '50.000,00'],
#    ['3.3.90.39.00', '950.000,00'],
#    ['3.3.90.40.00', '300.000,00'],
#    ['3.3.90.92.00', '500,00'])),
#  ('04.123.0439.2.020',
#   'MANUT.ATIVIDADES DA DIVISÃO DE COMPRAS',
#   9748,
#   9804,
#   (['3.1.90.11.00', '1.000,00'],
#    ['3.3.90.14.00', '1.000,00'],
#    ['3.3.90.30.00', '5.000,00'],
#    ['3.3.90.36.00', '2.000,00'],
#    ['3.3.90.39.00', '5.000,00'],
#    ['3.3.90.92.00', '400,00'])),
#  ('04.123.0439.2.021',
#   'MANUT.ATIV.DIVISÃO DE CONTABILIDADE',
#   9945,
#   9998,
#   (['3.1.90.11.00', '1.000,00'],
#    ['3.3.90.14.00', '500,00'],
#    ['3.3.90.30.00', '1.000,00'],
#    ['3.3.90.34.00', '500.000,00'],
#    ['3.3.90.36.00', '2.000,00'],
#    ['3.3.90.39.00', '50.000,00'],
#    ['3.3.90.92.00', '500,00'])),
#  ('28.843.2839.9.015',
#   'ENCARGOS C/A DÍVIDA INTERNA DO MUNICÍPIO',
#   10163,
#   10221,
#   (['4.6.90.71.00', '3.000.000,00'],
#    ['4.6.90.73.00', '500,00'],
#    ['4.6.90.75.00', '500,00'],
#    ['4.6.91.71.00', '4.500.000,00'])),
#  ('28.846.2839.9.011',
#   'CONTRIBUIÇÕES PARA O PASEP',
#   10752,
#   10796,
#   (['3.3.90.47.00', '2.800.000,00'],)),
#  ('28.846.2839.9.016',
#   'OUTROS ENCARGOS C/A DÍVIDA DO MUNICÍPIO',
#   10836,
#   10893,
#   (['3.1.90.91.00', '400.000,00'],
#    ['3.1.90.94.00', '10.000,00'],
#    ['3.2.90.21.00', '2.320.000,00'],
#    ['3.2.90.22.00', '1.000.000,00'],
#    ['3.2.90.25.00', '10.000,00'],
#    ['3.3.90.10.00', '500,00'],
#    ['3.3.90.31.00', '20.000,00'],
#    ['3.3.90.91.00', '250.000,00'],
#    ['3.3.90.93.00', '200.000,00'])),
#  ('12.306.1239.2.026',
#   'MANUT.ATIV.DA MERENDA ESCOLAR',
#   11563,
#   11610,
#   (['3.3.90.30.00', '3.750.000,00'],)),
#  ('12.361.1239.1.005',
#   'OBRAS,INSTAL.EQUIP.ENSINO FUNDAMENTAL',
#   11650,
#   11705,
#   (['4.4.90.51.00', '3.010.657,70'], ['4.4.90.52.00', '730.483,31'])),
#  ('12.361.1239.2.027',
#   'MANUT.DIVISÃO ADIMINIST.SEC. DE EDUCAÇÃO',
#   11769,
#   11827,
#   (['3.1.90.04.00', '6.000.000,00'],
#    ['3.1.90.11.00', '2.200.000,00'],
#    ['3.3.90.14.00', '5.000,00'],
#    ['3.3.90.30.00', '390.000,00'],
#    ['3.3.90.33.00', '1.000,00'],
#    ['3.3.90.34.00', '90.000,00'],
#    ['3.3.90.35.00', '500,00'],
#    ['3.3.90.36.00', '10.000,00'],
#    ['3.3.90.39.00', '1.350.000,00'],
#    ['3.3.90.40.00', '80.000,00'],
#    ['3.3.90.92.00', '500,00'])),
#  ('12.361.1239.2.028',
#   'MANUTENÇÃO DO ENSINO FUNDAMENTAL',
#   12097,
#   12147,
#   (['3.1.90.04.00', '200.000,00'],
#    ['3.1.90.11.00', '1.000.000,00'],
#    ['3.3.90.14.00', '2.000,00'],
#    ['3.3.90.30.00', '400.000,00'],
#    ['3.3.90.36.00', '10.000,00'],
#    ['3.3.90.39.00', '50.000,00'],
#    ['3.3.90.92.00', '200,00'])),
#  ('12.361.1239.2.029',
#   'ENCARGOS COM O TRANSPORTE ESCOLAR',
#   12323,
#   12374,
#   (['3.3.90.30.00', '10.000,00'],
#    ['3.3.90.36.00', '20.000,00'],
#    ['3.3.90.39.00', '9.000.000,00'],
#    ['3.3.90.92.00', '300,00'])),
#  ('12.361.1239.2.030',
#   'MANUT.ATIV.DIV. DE HIGIENE E ALIMENTAÇÃO',
#   12865,
#   12923,
#   (['3.1.90.04.00', '500.000,00'],
#    ['3.1.90.11.00', '4.400.000,00'],
#    ['3.3.90.14.00', '1.000,00'],
#    ['3.3.90.30.00', '20.000,00'],
#    ['3.3.90.34.00', '500,00'],
#    ['3.3.90.36.00', '4.000,00'],
#    ['3.3.90.39.00', '10.000,00'],
#    ['3.3.90.92.00', '400,00'])),
#  ('12.361.2839.9.017',
#   'ENCARGOS ESP. C/DESENVOLVIMENTO DO ENSINO',
#   13117,
#   13176,
#   (['3.1.90.13.00', '1.800.000,00'],
#    ['3.1.90.91.00', '500,00'],
#    ['3.1.90.94.00', '150.000,00'],
#    ['3.1.91.13.00', '2.100.000,00'],
#    ['3.2.90.22.00', '1.000,00'],
#    ['3.3.50.43.00', '1.000,00'],
#    ['3.3.60.41.00', '5.000,00'],
#    ['3.3.90.10.00', '400,00'],
#    ['3.3.90.18.00', '5.000,00'],
#    ['3.3.90.32.00', '2.000,00'],
#    ['3.3.90.91.00', '4.000,00'],
#    ['3.3.90.93.00', '14.230,19'],
#    ['3.3.91.97.00', '1.200.000,00'],
#    ['4.4.30.41.00', '2.000,00'],
#    ['4.6.90.71.00', '3.000,00'],
#    ['4.6.91.71.00', '5.000,00'])),
#  ('12.364.1239.2.032',
#   'ENCARGOS COM ENSINO SUPERIOR',
#   13553,
#   13599,
#   (['3.1.90.11.00', '650.000,00'],
#    ['3.3.90.30.00', '2.000,00'],
#    ['3.3.90.36.00', '2.000,00'],
#    ['3.3.90.39.00', '140.000,00'])),
#  ('12.364.2839.9.018',
#   'ENCARGOS ESPECIAIS C/O ENSINO SUPERIOR',
#   14117,
#   14173,
#   (['3.1.90.13.00', '1.000,00'],
#    ['3.1.91.13.00', '130.000,00'],
#    ['3.3.90.18.00', '1.000,00'],
#    ['3.3.90.32.00', '1.000,00'],
#    ['3.3.91.97.00', '70.000,00'])),
#  ('12.364.2839.9.059',
#   'TRANSFERÊNCIAS DE RECURSOS A UEG',
#   14298,
#   14348,
#   (['4.4.30.41.00', '10.000,00'],)),
#  ('12.364.2839.9.060',
#   'TRANSFERÊNCIAS DE RECURSOS A UFG',
#   14382,
#   14432,
#   (['4.4.20.41.00', '10.000,00'],)),
#  ('12.365.1239.1.007',
#   'OBRAS,INSTAL.EQUIP.P/ENSINO INFANTIL',
#   14466,
#   14520,
#   (['4.4.90.51.00', '341.158,95'], ['4.4.90.52.00', '150.000,00'])),
#  ('12.365.1239.2.033',
#   'MANUTENÇÃO DO ENSINO INFANTIL',
#   14580,
#   14627,
#   (['3.1.90.04.00', '30.000,00'],
#    ['3.1.90.11.00', '6.931.000,00'],
#    ['3.3.90.14.00', '2.000,00'],
#    ['3.3.90.30.00', '350.000,00'],
#    ['3.3.90.36.00', '3.000,00'],
#    ['3.3.90.39.00', '70.000,00'])),
#  ('12.365.2839.9.019',
#   'ENCARGOS ESPECIAIS C/ ENSINO INFANTIL',
#   14781,
#   14836,
#   (['3.1.90.94.00', '30.000,00'], ['3.3.90.32.00', '1.500,00'])),
#  ('12.366.1239.2.034',
#   'ENCARGOS C/EDUCAÇÃO JOVENS E ADULTOS',
#   14892,
#   14946,
#   (['3.1.90.04.00', '500,00'],
#    ['3.1.90.11.00', '5.000,00'],
#    ['3.1.90.16.00', '500,00'],
#    ['3.1.90.92.00', '400,00'],
#    ['3.3.90.30.00', '5.000,00'],
#    ['3.3.90.36.00', '2.000,00'],
#    ['3.3.90.39.00', '4.000,00'],
#    ['3.3.90.92.00', '400,00'])),
#  ('12.366.2839.9.020',
#   'FÉRIAS, INDENIZAÇÕES E REST. TRABALHISTAS - EJA',
#   15547,
#   15612,
#   (['3.1.90.94.00', '400,00'],)),
#  ('12.367.1239.2.035',
#   'ENCARGOS C/EDUCAÇÃO ESPECIAL',
#   15640,
#   15686,
#   (['3.1.90.04.00', '474,34'],
#    ['3.1.90.11.00', '4.743,40'],
#    ['3.1.90.16.00', '474,34'],
#    ['3.1.90.92.00', '474,34'],
#    ['3.3.90.30.00', '5.692,08'],
#    ['3.3.90.36.00', '4.743,40'],
#    ['3.3.90.39.00', '4.743,40'],
#    ['3.3.90.92.00', '474,34'])),
#  ('12.367.2839.9.021',
#   'FÉRIAS, INDENIZAÇÕES E REST. TRABALHISTAS',
#   15865,
#   15924,
#   (['3.1.90.94.00', '4.743,40'],)),
#  ('23.695.2339.1.013',
#   'OBRAS,INSTAL.EQUIP.DO POLO TURÍSTICO',
#   16410,
#   16464,
#   (['4.4.90.51.00', '40.000,00'], ['4.4.90.52.00', '20.000,00'])),
#  ('27.122.2739.1.008',
#   'OBRAS,INSTAL.EQUIP.DO DESPORTO E TURISMO',
#   16521,
#   16579,
#   (['4.4.90.51.00', '939.485,93'], ['4.4.90.52.00', '94.867,96'])),
#  ('27.122.2739.2.036',
#   'MANUT. SEC. ESPORTE E TURISMO',
#   16640,
#   16687,
#   (['3.1.90.11.00', '1.225.000,00'],
#    ['3.3.90.14.00', '13.000,00'],
#    ['3.3.90.30.00', '55.000,00'],
#    ['3.3.90.36.00', '25.000,00'],
#    ['3.3.90.39.00', '522.301,94'],
#    ['3.3.90.92.00', '900,00'])),
#  ('28.845.2839.9.022',
#   'TRANSFERÊNCIAS P/ APOIO AO DESPORTO E TURISMO',
#   16840,
#   16903,
#   (['3.3.50.41.00', '555.000,00'], ['3.3.50.43.00', '20.000,00'])),
#  ('28.845.2839.9.039',
#   'TRANSFERÊNCIAS A INSTITUIÇÕES PRIVADAS',
#   16962,
#   17018,
#   (['3.3.50.43.00', '20.000,00'], ['3.3.50.45.00', '120.000,00'])),
#  ('28.846.2839.9.023',
#   'ENCARGOS ESPECIAIS C/ DESPORTO E TURISMO',
#   17077,
#   17135,
#   (['3.1.90.94.00', '11.897,36'],
#    ['3.3.90.31.00', '10.000,00'],
#    ['3.3.90.32.00', '9.743,40'],
#    ['3.3.90.48.00', '60.000,00'])),
#  ('13.392.1339.1.009',
#   'OBR.INSTAL.EQUIP.DE DIFUSÃO CULTURAL',
#   17689,
#   17743,
#   (['4.4.90.51.00', '33.203,79'], ['4.4.90.52.00', '52.690,58'])),
#  ('13.392.1339.2.038',
#   'ENCARGOS C/A DIFUSÃO CULTURAL',
#   17800,
#   17847,
#   (['3.1.90.11.00', '850.000,00'],
#    ['3.3.90.14.00', '1.000,00'],
#    ['3.3.90.30.00', '15.000,00'],
#    ['3.3.90.34.00', '500,00'],
#    ['3.3.90.36.00', '20.000,00'],
#    ['3.3.90.39.00', '20.000,00'],
#    ['3.3.90.92.00', '400,00'])),
#  ('28.845.2839.9.024',
#   'TRANSFERÊNCIAS A INSTITUIÇÕES PRIVADAS',
#   18014,
#   18070,
#   (['3.3.50.41.00', '20.000,00'], ['3.3.50.43.00', '20.000,00'])),
#  ('28.846.2839.9.025',
#   'OUTROS ENCARGOS DA SECRETARIA DE CULTURA',
#   18127,
#   18185,
#   (['3.1.90.94.00', '15.000,00'],
#    ['3.3.90.10.00', '20.000,00'],
#    ['3.3.90.31.00', '30.000,00'],
#    ['3.3.90.32.00', '5.000,00'],
#    ['3.3.90.48.00', '15.000,00'])),
#  ('15.451.1539.1.010',
#   'OBRAS DE INFRA-ESTRUT.MELHORIAS URBANAS',
#   18771,
#   18828,
#   (['4.4.90.51.00', '14.584.600,70'],)),
#  ('15.451.1539.1.035',
#   'BENS MÓVEIS P/A SEC.DE OBRAS E PLAN.URBANO',
#   18870,
#   18930,
#   (['4.4.90.52.00', '15.000,00'],)),
#  ('15.451.1539.2.039',
#   'MANUT.ATIV.DIVISÃO DE OBRAS E PLAN. URBANO',
#   18964,
#   19024,
#   (['3.1.90.04.00', '500,00'],
#    ['3.1.90.11.00', '5.200.000,00'],
#    ['3.3.90.14.00', '3.000,00'],
#    ['3.3.90.30.00', '300.000,00'],
#    ['3.3.90.36.00', '150.000,00'],
#    ['3.3.90.37.00', '4.000,00'],
#    ['3.3.90.39.00', '400.000,00'],
#    ['3.3.90.92.00', '500,00'])),
#  ('15.451.1539.2.041',
#   'MANUT.DIVISÃO DE VIAS PÚBLICAS',
#   19220,
#   19268,
#   (['3.1.90.04.00', '400,00'],
#    ['3.1.90.11.00', '2.000,00'],
#    ['3.3.90.30.00', '1.375.637,77'],
#    ['3.3.90.36.00', '10.000,00'],
#    ['3.3.90.39.00', '80.000,00'],
#    ['3.3.90.92.00', '500,00'])),
#  ('15.846.2839.9.026',
#   'FÉRIAS, INDENIZAÇÕES E REST. TRABALHISTAS',
#   19416,
#   19475,
#   (['3.1.90.94.00', '120.000,00'],)),
#  ('26.781.2639.1.040',
#   'OBRAS DO AEROPORTO DE CARGAS E PASSAG.DE JATAÍ',
#   19511,
#   19575,
#   (['4.4.90.51.00', '2.381.962,03'],
#    ['4.4.90.52.00', '47.433,98'],
#    ['4.4.90.61.00', '28.460,39'])),
#  ('08.122.0839.1.015',
#   'OBRAS,INSTAL.EQUIP.ASSIST.SOCIAL GERAL',
#   20150,
#   20206,
#   (['4.4.90.51.00', '123.328,35'],
#    ['4.4.90.52.00', '58.818,14'],
#    ['4.4.90.61.00', '18.973,59'])),
#  ('08.122.0839.2.045',
#   'MANUT.DIVISÃO PROM.ASSISTÊNCIA SOCIAL',
#   20288,
#   20343,
#   (['3.1.90.04.00', '210.000,00'],
#    ['3.1.90.11.00', '3.100.000,00'],
#    ['3.3.90.14.00', '1.000,00'],
#    ['3.3.90.30.00', '5.000,00'],
#    ['3.3.90.33.00', '2.000,00'],
#    ['3.3.90.36.00', '44.743,40'],
#    ['3.3.90.39.00', '309.486,80'],
#    ['3.3.90.92.00', '974,34'])),
#  ('08.243.0839.2.075',
#   'MANUTENÇÃO DAS ATIV. DO CONSELHO TUTELAR',
#   20540,
#   20598,
#   (['3.1.90.11.00', '202.000,00'],
#    ['3.3.90.14.00', '1.000,00'],
#    ['3.3.90.30.00', '1.000,00'],
#    ['3.3.90.36.00', '1.000,00'],
#    ['3.3.90.39.00', '3.000,00'],
#    ['3.3.90.92.00', '100,00'])),
#  ('08.845.2839.9.030',
#   'TRANSFERÊNCIAS A INSTITUIÇÕES PRIVADAS',
#   20742,
#   20798,
#   (['3.3.50.43.00', '3.055.000,00'], ['3.3.60.41.00', '20.000,00'])),
#  ('08.846.2839.9.031',
#   'OUTROS ENC.ESP.DA SEC.DESENVOL. SOCIAL',
#   20861,
#   20917,
#   (['3.1.90.91.00', '1.000,00'],
#    ['3.1.90.94.00', '40.000,00'],
#    ['3.3.90.31.00', '1.000,00'],
#    ['3.3.90.32.00', '2.000,00'],
#    ['3.3.90.46.00', '500,00'],
#    ['3.3.90.48.00', '1.000,00'],
#    ['3.3.90.49.00', '1.000,00'],
#    ['3.3.90.91.00', '5.000,00'],
#    ['3.3.90.93.00', '5.000,00'])),
#  ('16.244.1639.1.016',
#   'OBRAS,INSTAL.EQUIP.PARA HABITAÇÕES POPULARES',
#   21575,
#   21637,
#   (['4.4.90.51.00', '350.000,00'],
#    ['4.4.90.52.00', '37.947,18'],
#    ['4.4.90.61.00', '14.230,19'])),
#  ('20.122.2039.1.017',
#   'OBRAS,INSTAL.EQUIP.AGRICULT.E PECUÁRIA',
#   22201,
#   22257,
#   (['4.4.90.51.00', '55.504,11'],
#    ['4.4.90.52.00', '673.562,53'],
#    ['4.4.90.61.00', '9.486,80'])),
#  ('20.606.2039.2.050',
#   'MANUT. DA SEC. DO DESENV. RURAL',
#   22338,
#   22387,
#   (['3.1.90.11.00', '1.900.000,00'],
#    ['3.3.90.14.00', '4.000,00'],
#    ['3.3.90.30.00', '140.000,00'],
#    ['3.3.90.36.00', '105.000,00'],
#    ['3.3.90.39.00', '140.000,00'],
#    ['3.3.90.92.00', '800,00'])),
#  ('28.845.2839.9.033',
#   'TRANSFERÊNCIAS A INSTITUIÇÕES PRIVADAS',
#   22541,
#   22597,
#   (['3.3.50.43.00', '10.000,00'], ['3.3.60.41.00', '410.000,00'])),
#  ('28.846.2839.9.034',
#   'ENCAR. ESP.DA SEC. AGRICULTURA E PECUÁRIA',
#   22656,
#   22715,
#   (['3.1.90.94.00', '15.000,00'],
#    ['3.3.90.91.00', '500,00'],
#    ['4.4.30.42.00', '2.000,00'])),
#  ('15.452.1539.1.018',
#   'OBRAS,INSTAL.EQUIP.SERVIÇOS URBANOS',
#   23271,
#   23324,
#   (['4.4.90.51.00', '1.337.638,27'],
#    ['4.4.90.52.00', '66.407,57'],
#    ['4.4.90.61.00', '47.433,98'])),
#  ('15.452.1539.2.052',
#   'MANUT.SEC.MEIO AMB. E SERVIÇOS URBANOS',
#   23410,
#   23466,
#   (['3.1.90.04.00', '500,00'],
#    ['3.1.90.11.00', '5.200.000,00'],
#    ['3.3.90.14.00', '15.000,00'],
#    ['3.3.90.30.00', '470.000,00'],
#    ['3.3.90.35.00', '500,00'],
#    ['3.3.90.36.00', '260.000,00'],
#    ['3.3.90.37.00', '2.000,00'],
#    ['3.3.90.39.00', '939.993,58'],
#    ['3.3.90.92.00', '1.000,00'])),
#  ('15.452.1539.2.054',
#   'MANUT.DEPART.COLETA DE LIXO DOMICILIAR',
#   23685,
#   23741,
#   (['3.3.90.30.00', '10.000,00'],
#    ['3.3.90.36.00', '10.000,00'],
#    ['3.3.90.39.00', '7.970.000,00'])),
#  ('15.452.1539.2.056',
#   'MANUT. DE PRAÇAS, PARQUES E JARDINS',
#   23827,
#   23880,
#   (['3.1.90.11.00', '1.000,00'],
#    ['3.3.90.30.00', '25.000,00'],
#    ['3.3.90.36.00', '15.000,00'],
#    ['3.3.90.39.00', '270.000,00'],
#    ['4.4.90.52.00', '30.000,00'])),
#  ('17.512.1739.1.011',
#   'OBRAS E EQUIP.SANEAMENTO BÁSICO URBANO',
#   24007,
#   24063,
#   (['4.4.90.51.00', '113.841,55'],
#    ['4.4.90.52.00', '9.486,80'],
#    ['4.4.90.61.00', '47.433,98'])),
#  ('17.512.1739.1.036',
#   'OBRAS CONSÓRCIO INTERM.RESÍDUOS SÓLIDOS',
#   24144,
#   24201,
#   (['4.4.71.70.00', '10.000,00'],)),
#  ('17.512.1739.2.071',
#   'MANUT.CONSÓRCIO INTERM.RESÍDUOS SÓLIDOS',
#   24235,
#   24292,
#   (['3.1.71.70.00', '14.230,19'], ['3.3.71.70.00', '14.230,19'])),
#  ('17.845.2839.9.027',
#   'TRANSF.CONSÓRCIO INTERM.RESÍDUOS SÓLIDOS',
#   24798,
#   24856,
#   (['3.3.71.43.00', '5.000,00'],)),
#  ('18.122.1839.1.014',
#   'OBRAS,INSTAL.EQUIP.GESTÃO AMBIENTAL',
#   24888,
#   24941,
#   (['4.4.90.51.00', '340.000,52'],
#    ['4.4.90.52.00', '18.973,59'],
#    ['4.4.90.61.00', '9.486,80'])),
#  ('25.122.1539.1.039',
#   'BENS MÓVEIS P/ILUMINAÇÃO PÚBLICA',
#   25022,
#   25072,
#   (['4.4.90.52.00', '5.000,00'],)),
#  ('25.122.1539.2.055',
#   'MANUT.DEPARTAMENTO DE ILUMINAÇÃO PÚBLICA',
#   25104,
#   25162,
#   (['3.1.90.11.00', '130.000,00'],
#    ['3.3.90.14.00', '1.000,00'],
#    ['3.3.90.30.00', '343.720,22'],
#    ['3.3.90.36.00', '10.000,00'],
#    ['3.3.90.37.00', '500,00'],
#    ['3.3.90.39.00', '4.395.000,00'],
#    ['3.3.90.92.00', '200,00'])),
#  ('28.122.2839.9.029',
#   'ENCARGOS ESPECIAIS DA SEC. MEIO AMB. SERV. URBANOS',
#   25335,
#   25403,
#   (['3.1.90.94.00', '45.000,00'],
#    ['3.3.50.43.00', '20.000,00'],
#    ['3.3.90.91.00', '400,00'])),
#  ('19.573.1939.1.037',
#   'OBRAS,INSTAL.EQUIP.P/ SEC. DESENV. ECONÔMICO',
#   25965,
#   26027,
#   (['4.4.90.51.00', '56.920,78'], ['4.4.90.52.00', '9.486,80'])),
#  ('19.573.1939.2.072',
#   'MANUT. DA SUP. DE CIÊNCIA, TECNOL. E INOVAÇÃO',
#   26083,
#   26146,
#   (['3.3.90.14.00', '3.000,00'],
#    ['3.3.90.30.00', '3.000,00'],
#    ['3.3.90.36.00', '25.000,00'],
#    ['3.3.90.39.00', '10.000,00'],
#    ['3.3.90.92.00', '400,00'])),
#  ('22.661.2239.1.012',
#   'OBRAS,INSTAL.EQUIP.DIST.INDUSTRIAL',
#   26267,
#   26319,
#   (['4.4.90.51.00', '72.301,94'],
#    ['4.4.90.52.00', '23.716,99'],
#    ['4.4.90.61.00', '37.947,18'])),
#  ('22.661.2239.2.042',
#   'MANUT.ATIV.DA SEC. DESENVOLVIMENTO ECONÔMICO',
#   26400,
#   26462,
#   (['3.1.90.11.00', '630.000,00'],
#    ['3.3.90.14.00', '2.500,00'],
#    ['3.3.90.30.00', '20.000,00'],
#    ['3.3.90.36.00', '10.000,00'],
#    ['3.3.90.39.00', '20.000,00'],
#    ['3.3.90.92.00', '500,00'])),
#  ('28.845.2839.9.037',
#   'TRANSFERÊNCIAS A INSTITUIÇÕES PRIVADAS',
#   26609,
#   26665,
#   (['3.3.50.41.00', '20.000,00'],)),
#  ('28.846.2839.9.028',
#   'ENCARGOS ESP.COM SEC. DESENVOLVIMENTO ECONÔMICO',
#   26699,
#   26764,
#   (['3.1.90.94.00', '10.000,00'],
#    ['3.3.90.18.00', '2.000,00'],
#    ['3.3.90.20.00', '5.000,00'],
#    ['3.3.90.31.00', '2.000,00'])),
#  ('28.846.2839.9.038',
#   'FÉRIAS, INDENIZAÇÕES E REST. TRABALHISTAS',
#   26864,
#   26923,
#   (['3.1.90.94.00', '10.000,00'],)),
#  ('13.392.1339.1.041',
#   'OBRAS,INSTAL. E EQUIP. P/O FUNDO DE CULTURA',
#   27419,
#   27480,
#   (['4.4.90.51.00', '273.716,99'], ['4.4.90.52.00', '18.973,59'])),
#  ('13.392.1339.2.074',
#   'MANUTENÇÃO DAS ATIV. DO FUNDO DE CULTURA',
#   27539,
#   27597,
#   (['3.1.90.11.00', '2.000,00'],
#    ['3.3.90.14.00', '500,00'],
#    ['3.3.90.30.00', '10.000,00'],
#    ['3.3.90.36.00', '10.000,00'],
#    ['3.3.90.39.00', '10.000,00'],
#    ['3.3.90.92.00', '200,00'])),
#  ('28.845.2839.9.043',
#   'TRANSFERÊNCIAS A INSTITUIÇÕES PRIVADAS',
#   27739,
#   27795,
#   (['3.3.50.43.00', '20.000,00'], ['3.3.60.41.00', '5.000,00'])),
#  ('28.846.2839.9.044',
#   'ENCARGOS ESPECIAIS DO FUNDO DE CULTURA',
#   27851,
#   27907,
#   (['3.1.90.94.00', '2.000,00'],
#    ['3.3.90.10.00', '102.000,00'],
#    ['3.3.90.31.00', '2.000,00'],
#    ['3.3.90.32.00', '2.000,00'])),
#  ('06.181.0639.1.032',
#   'BENS MÓVEIS P/ SEC.SEG.PUBLICA, SUP.DE TRANSITO, E PROCON',
#   28479,
#   28554,
#   (['4.4.90.52.00', '44.199,31'],)),
#  ('06.181.0639.2.015',
#   'MANUT. SEC.SEG.PUBLICA, SUP.DE TRANSITO, E PROCON',
#   28588,
#   28655,
#   (['3.1.90.04.00', '900,00'],
#    ['3.1.90.11.00', '3.630.000,00'],
#    ['3.1.90.94.00', '8.000,00'],
#    ['3.3.90.14.00', '5.000,00'],
#    ['3.3.90.30.00', '85.000,00'],
#    ['3.3.90.34.00', '10.000,00'],
#    ['3.3.90.36.00', '65.000,00'],
#    ['3.3.90.39.00', '520.000,00'],
#    ['3.3.90.92.00', '900,00'],
#    ['3.3.90.93.00', '400.000,00'])),
#  ('99.999.9999.9.999',
#   'RESERVA DE CONTIGENCIA',
#   29365,
#   29405,
#   (['9.9.99.99.99', '830.094,67'],)),
#  ('12.361.1239.2.057',
#   'MANUT.DAS ATIVIDADES DO FUNDEB - 60%',
#   29948,
#   30002,
#   (['3.1.90.04.00', '500,00'], ['3.1.90.11.00', '22.841.367,00'])),
#  ('12.361.1239.2.058',
#   'MANUT.DAS ATIVIDADES DO FUNDEB - 40%',
#   30064,
#   30118,
#   (['3.1.90.04.00', '500,00'],
#    ['3.1.90.11.00', '4.400.000,00'],
#    ['3.3.90.14.00', '1.000,00'],
#    ['3.3.90.30.00', '3.000,00'],
#    ['3.3.90.36.00', '2.000,00'],
#    ['3.3.90.39.00', '3.000,00'])),
#  ('12.361.2839.9.045',
#   'ENCARGOS ESPECIAIS DO FUNDEB - 60%',
#   30266,
#   30318,
#   (['3.1.90.13.00', '2.000,00'],
#    ['3.1.90.91.00', '2.000,00'],
#    ['3.1.90.94.00', '200.000,00'],
#    ['3.1.91.13.00', '2.200.000,00'],
#    ['3.3.91.97.00', '1.500.000,00'])),
#  ('12.361.2839.9.046',
#   'ENCARGOS ESPECIAIS DO FUNDEB - 40%',
#   30452,
#   30504,
#   (['3.1.90.13.00', '5.000,00'],
#    ['3.1.90.91.00', '1.000,00'],
#    ['3.1.90.94.00', '30.000,00'],
#    ['3.1.91.13.00', '500.000,00'],
#    ['3.3.90.91.00', '1.000,00'],
#    ['3.3.91.97.00', '300.000,00'])),
#  ('12.365.1239.2.059',
#   'MANUT.ATIV. DO ENSINO INFANTIL - 60%',
#   30653,
#   30707,
#   (['3.1.90.04.00', '500,00'],
#    ['3.1.90.11.00', '5.000.000,00'],
#    ['3.1.90.94.00', '50.000,00'],
#    ['3.1.91.13.00', '1.300.000,00'],
#    ['3.3.91.97.00', '1.000.000,00'])),
#  ('12.365.1239.2.060',
#   'MANUT.ATIV. DO ENSINO INFANTIL - 40%',
#   30842,
#   30896,
#   (['3.1.90.04.00', '200,00'],
#    ['3.1.90.11.00', '500.000,00'],
#    ['3.1.90.94.00', '20.000,00'],
#    ['3.1.91.13.00', '250.000,00'],
#    ['3.3.91.97.00', '150.000,00'])),
#  ('12.364.1239.1.020',
#   'OBRAS,INSTAL.EQUIP.P/FUND.EDUCACIONAL DE JATAÍ',
#   31960,
#   32024,
#   (['4.4.90.52.00', '1.500,00'],)),
#  ('12.364.1239.2.061',
#   'MANUT.ATIV.FUN.EDUCACIONAL DE JATAÍ',
#   32056,
#   32109,
#   (['3.1.90.11.00', '3.000,00'],
#    ['3.3.90.14.00', '300,00'],
#    ['3.3.90.30.00', '2.000,00'],
#    ['3.3.90.33.00', '950,00'],
#    ['3.3.90.34.00', '33.000,00'],
#    ['3.3.90.36.00', '1.000,00'],
#    ['3.3.90.39.00', '4.000,00'],
#    ['3.3.90.48.00', '50.000,00'],
#    ['3.3.90.92.00', '100,00'])),
#  ('12.364.2839.9.047',
#   'ENCARGOS ESPECIAIS DA FUND.EDUCACIONAL',
#   32314,
#   32370,
#   (['3.1.90.13.00', '6.000,00'],
#    ['3.1.90.94.00', '1.000,00'],
#    ['3.1.91.13.00', '1.000,00'],
#    ['3.2.90.22.00', '1.000,00'],
#    ['3.3.30.41.00', '82.619,07'],
#    ['3.3.90.18.00', '500,00'],
#    ['3.3.90.20.00', '500,00'],
#    ['3.3.90.32.00', '900,00'],
#    ['3.3.90.91.00', '500,00'],
#    ['3.3.90.93.00', '500,00'],
#    ['4.6.90.71.00', '5.000,00'],
#    ['4.6.91.71.00', '1.000,00'])),
#  ('10.122.1039.1.021',
#   'OBRAS,INSTAL.EQUIP.P/ SAÚDE EM GERAL',
#   33142,
#   33196,
#   (['4.4.90.51.00', '400.000,00'], ['4.4.90.52.00', '702.800,20'])),
#  ('10.122.1039.2.062',
#   'MANUT.DIR.GERAL DE PLANEJ.E GESTÃO ADM',
#   33258,
#   33314,
#   (['3.1.90.04.00', '300,00'],
#    ['3.1.90.11.00', '2.600.000,00'],
#    ['3.3.90.14.00', '225.000,00'],
#    ['3.3.90.30.00', '200.000,00'],
#    ['3.3.90.33.00', '5.000,00'],
#    ['3.3.90.34.00', '300.000,00'],
#    ['3.3.90.36.00', '80.000,00'],
#    ['3.3.90.39.00', '1.400.000,00'],
#    ['3.3.90.40.00', '150.000,00'],
#    ['3.3.90.92.00', '100,00'])),
#  ('10.122.1039.2.076',
#   'MANUTENÇÃO DO CONSELHO MUN. DE SAÚDE',
#   33561,
#   33615,
#   (['3.3.90.30.00', '4.000,00'],
#    ['3.3.90.36.00', '3.000,00'],
#    ['3.3.90.39.00', '2.000,00'])),
#  ('10.122.1039.2.086',
#   'MANUT. DE CONSÓRCIO INTERMUNICIPAL DE SAÚDE',
#   33691,
#   33752,
#   (['3.1.71.70.00', '4.000,00'],
#    ['3.3.71.70.00', '4.000,00'],
#    ['4.4.71.70.00', '4.000,00'])),
#  ('10.122.2839.9.048',
#   'ENCARGOS ESPECIAIS DA SAÚDE EM GERAL',
#   33829,
#   33883,
#   (['3.1.90.13.00', '6.800.000,00'],
#    ['3.1.90.91.00', '20.000,00'],
#    ['3.1.90.94.00', '50.000,00'],
#    ['3.1.91.13.00', '2.600.000,00'],
#    ['3.2.90.22.00', '215.000,00'],
#    ['3.3.50.43.00', '80.000,00'],
#    ['3.3.60.41.00', '500,00'],
#    ['3.3.90.10.00', '400,00'],
#    ['3.3.90.32.00', '5.000,00'],
#    ['3.3.90.46.00', '340.000,00'],
#    ['3.3.90.48.00', '500,00'],
#    ['3.3.90.49.00', '450.000,00'],
#    ['3.3.90.91.00', '150.000,00'],
#    ['3.3.91.97.00', '1.200.000,00'],
#    ['4.6.90.71.00', '10.000,00'],
#    ['4.6.91.71.00', '140.000,00'])),
#  ('10.301.1039.2.077',
#   'MANUTENÇÃO DO BLOCO DE ATENÇÃO BÁSICA',
#   34688,
#   34743,
#   (['3.1.90.04.00', '500,00'],
#    ['3.1.90.11.00', '7.600.000,00'],
#    ['3.3.90.30.00', '1.500.000,00'],
#    ['3.3.90.34.00', '7.000.000,00'],
#    ['3.3.90.36.00', '30.000,00'],
#    ['3.3.90.39.00', '600.000,00'],
#    ['3.3.90.92.00', '400,00'])),
#  ('10.302.1039.2.078',
#   'MANUTENÇÃO DO BLOCO MÉDIA E ALTA COMPLEXIDADE',
#   34923,
#   34986,
#   (['3.1.90.04.00', '400,00'],
#    ['3.1.90.11.00', '8.380.000,00'],
#    ['3.3.90.30.00', '4.200.000,00'],
#    ['3.3.90.34.00', '20.030.000,00'],
#    ['3.3.90.36.00', '10.000,00'],
#    ['3.3.90.39.00', '11.379.000,00'],
#    ['3.3.90.92.00', '474,34'])),
#  ('10.302.1039.2.088',
#   'MANUTENÇAO DA UNIDADE DE PRONTO ATENDIMENTO - UPA',
#   35170,
#   35237,
#   (['3.1.90.04.00', '400,00'],
#    ['3.1.90.11.00', '70.000,00'],
#    ['3.3.90.30.00', '40.000,00'],
#    ['3.3.90.34.00', '2.144,35'],
#    ['3.3.90.36.00', '5.000,00'],
#    ['3.3.90.39.00', '21.000,00'],
#    ['3.3.90.92.00', '300,00'])),
#  ('10.302.1039.2.089',
#   'MANUTENÇAO CENTRO DE ATENÇAO PSICOSSOCIAL - CAPS',
#   35833,
#   35899,
#   (['3.1.90.04.00', '400,00'],
#    ['3.1.90.11.00', '1.000.000,00'],
#    ['3.3.90.30.00', '300.000,00'],
#    ['3.3.90.34.00', '650.000,00'],
#    ['3.3.90.36.00', '40.000,00'],
#    ['3.3.90.39.00', '300.000,00'],
#    ['3.3.90.92.00', '500,00'])),
#  ('10.303.1039.2.079',
#   'MANUTENÇÃO DO BLOCO ASSISTÊNCIA FARMACÊUTICA',
#   36074,
#   36136,
#   (['3.3.90.30.00', '600.000,00'],
#    ['3.3.90.32.00', '40.000,00'],
#    ['3.3.90.36.00', '2.000,00'])),
#  ('10.304.1039.2.080',
#   'MANUTENÇÃO DO BLOCO DE VIGILÂNCIA SANITÁRIA',
#   36217,
#   36278,
#   (['3.1.90.04.00', '400,00'],
#    ['3.1.90.11.00', '1.200.000,00'],
#    ['3.3.90.30.00', '100.000,00'],
#    ['3.3.90.34.00', '3.000,00'],
#    ['3.3.90.36.00', '3.000,00'],
#    ['3.3.90.39.00', '20.000,00'],
#    ['3.3.90.92.00', '500,00'])),
#  ('10.305.1039.2.081',
#   'AÇÕES DE COMBATE A DENGUE DOENÇAS EPIDEMIOLÓGICAS',
#   36449,
#   36516,
#   (['3.1.90.04.00', '400,00'],
#    ['3.1.90.11.00', '1.600.000,00'],
#    ['3.3.90.30.00', '150.000,00'],
#    ['3.3.90.34.00', '180.000,00'],
#    ['3.3.90.36.00', '40.000,00'],
#    ['3.3.90.39.00', '50.000,00'],
#    ['3.3.90.92.00', '400,00'])),
#  ('18.541.1839.1.022',
#   'OBRAS,INSTAL.EQUIP.FUN.MUN.MEIO AMBIENTE',
#   37638,
#   37696,
#   (['4.4.90.51.00', '155.769,34'], ['4.4.90.52.00', '18.973,59'])),
#  ('18.541.1839.2.063',
#   'MANUT.ATIV.DO FUNDO MUN.MEIO AMBIENTE',
#   37755,
#   37810,
#   (['3.1.90.04.00', '300,00'],
#    ['3.1.90.11.00', '10.000,00'],
#    ['3.3.90.14.00', '2.000,00'],
#    ['3.3.90.30.00', '40.000,00'],
#    ['3.3.90.34.00', '2.000,00'],
#    ['3.3.90.36.00', '20.000,00'],
#    ['3.3.90.39.00', '30.000,00'],
#    ['3.3.90.92.00', '100,00'])),
#  ('18.541.2839.9.049',
#   'ENCARGOS ESPECIAIS DO FUNDO DO MEIO AMBIENTE',
#   37998,
#   38060,
#   (['3.1.90.13.00', '3.000,00'],
#    ['3.1.90.94.00', '1.000,00'],
#    ['3.1.91.13.00', '1.000,00'],
#    ['3.3.50.43.00', '1.000,00'],
#    ['3.3.90.32.00', '1.000,00'],
#    ['4.6.90.71.00', '500,00'])),
#  ('09.272.0939.1.023',
#   'OBRAS,INSTAL.EQUIP. P/ JATAIPREV',
#   38690,
#   38740,
#   (['4.4.90.51.00', '78.460,39'], ['4.4.90.52.00', '47.433,98'])),
#  ('09.272.0939.2.064',
#   'ENC.C/PREV.SOCIAL E SEGURIDADE MUNICIPAL',
#   38798,
#   38856,
#   (['3.1.90.11.00', '250.000,00'],
#    ['3.3.90.14.00', '2.000,00'],
#    ['3.3.90.30.00', '25.000,00'],
#    ['3.3.90.34.00', '110.000,00'],
#    ['3.3.90.36.00', '50.000,00'],
#    ['3.3.90.39.00', '500.000,00'],
#    ['3.3.90.40.00', '40.000,00'],
#    ['3.3.90.47.00', '300.000,00'],
#    ['3.3.90.92.00', '100,00'])),
#  ('09.272.2839.9.050',
#   'ENCARGOS ESPECIAIS DO JATAIPREV',
#   39077,
#   39126,
#   (['3.1.90.01.00', '26.700.000,00'],
#    ['3.1.90.03.00', '3.000.000,00'],
#    ['3.1.90.05.00', '800.000,00'],
#    ['3.1.90.08.00', '500,00'],
#    ['3.1.90.09.00', '40.000,00'],
#    ['3.1.90.13.00', '40.000,00'],
#    ['3.1.90.91.00', '30.000,00'],
#    ['3.1.91.13.00', '20.000,00'],
#    ['3.2.90.22.00', '100,00'],
#    ['3.3.90.91.00', '30.000,00'],
#    ['3.3.90.93.00', '1.000,00'])),
#  ('99.999.7999.7.999',
#   'RESERVA TÉCNICA DO RPPS',
#   39815,
#   39856,
#   (['7.7.99.99.99', '385.138,52'],)),
#  ('06.182.0439.1.024',
#   'OBRAS,INSTAL.EQUIP. P/O FEMBOM',
#   40392,
#   40440,
#   (['4.4.90.51.00', '57.204,11'], ['4.4.90.52.00', '47.433,98'])),
#  ('06.182.0439.2.065',
#   'MANUTENÇÃO DAS ATIVIDADES DO FEMBOM',
#   40498,
#   40551,
#   (['3.1.90.11.00', '41.362,42'],
#    ['3.1.90.34.00', '948,68'],
#    ['3.3.90.14.00', '19.256,93'],
#    ['3.3.90.30.00', '133.381,81'],
#    ['3.3.90.34.00', '28.460,39'],
#    ['3.3.90.36.00', '9.486,80'],
#    ['3.3.90.39.00', '176.152,59'],
#    ['3.3.90.40.00', '15.000,00'],
#    ['3.3.90.92.00', '94,87'])),
#  ('06.182.2839.9.051',
#   'ENCARGOS ESPECIAIS DO FEMBOM',
#   40764,
#   40810,
#   (['3.1.90.13.00', '4.743,40'],
#    ['3.3.50.43.00', '948,68'],
#    ['3.3.90.32.00', '1.138,42'])),
#  ('08.243.0839.1.038',
#   'OBRAS,INSTAL.EQUIP.P/F.M.D.C.ADOLESCENTE',
#   41432,
#   41490,
#   (['4.4.90.52.00', '1.000,00'],)),
#  ('08.243.0839.2.073',
#   'ENC.C/FUNDO MUN.DIR.CRIANÇA/ADOLESCENTE',
#   41522,
#   41579,
#   (['3.3.90.30.00', '2.000,00'],
#    ['3.3.90.33.00', '500,00'],
#    ['3.3.90.36.00', '3.000,00'],
#    ['3.3.90.39.00', '5.000,00'],
#    ['3.3.90.92.00', '100,00'])),
#  ('28.845.2839.9.035',
#   'TRANSF.A INSTITUIÇÕES PRIVADAS P/APOIO AO FMDCA',
#   41696,
#   41761,
#   (['3.3.50.43.00', '85.000,00'],)),
#  ('28.846.2839.9.036',
#   'DOAÇÃO DE MATERIAIS P/APOIO AS ATIV.FMDCA',
#   41795,
#   41854,
#   (['3.3.90.32.00', '1.000,00'],)),
#  ('19.573.1839.2.066',
#   'MANUT.ATIV.FUNDO MUN.CIÊNCIA E TECNOLOGIA',
#   42453,
#   42512,
#   (['3.1.90.04.00', '948,68'],
#    ['3.1.90.11.00', '4.743,40'],
#    ['3.1.90.16.00', '474,34'],
#    ['3.1.90.34.00', '948,68'],
#    ['3.1.90.92.00', '474,34'],
#    ['3.3.90.14.00', '1.897,36'],
#    ['3.3.90.30.00', '4.743,40'],
#    ['3.3.90.34.00', '948,68'],
#    ['3.3.90.36.00', '4.743,40'],
#    ['3.3.90.39.00', '4.743,40'],
#    ['3.3.90.92.00', '474,34'])),
#  ('19.573.2839.9.052',
#   'ENCARGOS ESPECIAIS DO FDO. C.E TECNOLOGIA',
#   42753,
#   42812,
#   (['3.1.90.13.00', '474,34'],
#    ['3.1.90.92.00', '237,17'],
#    ['3.1.90.94.00', '474,34'],
#    ['3.1.91.13.00', '948,68'],
#    ['3.1.91.92.00', '237,17'],
#    ['3.3.50.43.00', '1.423,02'],
#    ['3.3.90.20.00', '6.735,62'],
#    ['3.3.90.32.00', '474,34'])),
#  ('04.422.0439.1.042',
#   'BENS MÓVEIS P/FDO.DE DEFESA DO CONSUMIDOR',
#   43531,
#   43590,
#   (['4.4.90.52.00', '20.000,00'],)),
#  ('04.422.0439.2.067',
#   'MANUT.ATIV.FUNDO MUN.DEFESA DO CONSUMIDOR',
#   43624,
#   43683,
#   (['3.1.90.11.00', '1.000,00'],
#    ['3.3.90.14.00', '1.000,00'],
#    ['3.3.90.30.00', '20.000,00'],
#    ['3.3.90.34.00', '1.500,00'],
#    ['3.3.90.36.00', '1.500,00'],
#    ['3.3.90.39.00', '30.000,00'],
#    ['3.3.90.92.00', '100,00'])),
#  ('04.422.2839.9.053',
#   'ENCARGOS ESP.DO FDO.DEFESA CONSUMIDOR',
#   43848,
#   43903,
#   (['3.1.90.13.00', '500,00'],
#    ['3.1.90.94.00', '500,00'],
#    ['3.1.91.13.00', '500,00'],
#    ['3.3.90.32.00', '500,00'])),
#  ('08.122.0839.1.026',
#   'OBRAS,INSTAL.EQUIP.FUNDO MUN.ASSIST.SOCIAL',
#   44528,
#   44588,
#   (['4.4.90.51.00', '37.655,72'], ['4.4.90.52.00', '57.696,70'])),
#  ('08.122.0839.2.068',
#   'MANUT.DIVISÃO PROM.ASSISTÊNCIA SOCIAL',
#   44645,
#   44700,
#   (['3.1.90.04.00', '500,00'],
#    ['3.1.90.11.00', '500,00'],
#    ['3.3.90.14.00', '6.000,00'],
#    ['3.3.90.30.00', '100.000,00'],
#    ['3.3.90.33.00', '4.000,00'],
#    ['3.3.90.34.00', '85.000,00'],
#    ['3.3.90.36.00', '3.500,00'],
#    ['3.3.90.39.00', '25.000,00'],
#    ['3.3.90.92.00', '100,00'])),
#  ('08.122.0839.2.069',
#   'MANUT.DEPART.DE PROGRAMAS E PROJETOS',
#   44908,
#   44962,
#   (['3.3.90.30.00', '500,00'],
#    ['3.3.90.36.00', '1.000,00'],
#    ['3.3.90.39.00', '2.000,00'])),
#  ('08.122.2839.9.054',
#   'ENCARGOS ESPECIAIS DA ASSIST.SOCIAL GERAL',
#   45036,
#   45095,
#   (['3.1.90.13.00', '2.000,00'],
#    ['3.1.90.94.00', '1.000,00'],
#    ['3.1.91.13.00', '1.000,00'],
#    ['3.3.50.43.00', '46.000,00'],
#    ['3.3.90.32.00', '150.000,00'],
#    ['3.3.90.48.00', '1.000,00'],
#    ['3.3.90.91.00', '500,00'],
#    ['3.3.90.93.00', '500,00'],
#    ['3.3.91.47.00', '500,00'])),
#  ('08.241.0839.2.090',
#   'MANUTENÇÃO DO FUNDO MUNICIPAL DO IDOSO',
#   45302,
#   45358,
#   (['3.3.50.43.00', '54.000,00'],
#    ['3.3.90.30.00', '20.000,00'],
#    ['3.3.90.39.00', '1.000,00'])),
#  ('08.244.0839.2.083',
#   'BLOCO P.S.E(PAEFI,MSE,PACI,CREAS,IDOSO,PTMC,ETC)',
#   45879,
#   45945,
#   (['3.1.90.04.00', '400,00'],
#    ['3.1.90.11.00', '1.000,00'],
#    ['3.3.90.30.00', '270.000,00'],
#    ['3.3.90.32.00', '5.000,00'],
#    ['3.3.90.36.00', '3.000,00'],
#    ['3.3.90.39.00', '130.000,00'],
#    ['3.3.90.92.00', '100,00'])),
#  ('08.244.0839.2.084',
#   'BLOCO P.S.B (SCFV,PBF,CRAS,PBV III E OUTROS)',
#   46111,
#   46173,
#   (['3.1.90.04.00', '1.000,00'],
#    ['3.1.90.11.00', '3.500,00'],
#    ['3.3.90.30.00', '352.500,00'],
#    ['3.3.90.36.00', '4.000,00'],
#    ['3.3.90.39.00', '36.000,00'],
#    ['3.3.90.92.00', '100,00'])),
#  ('08.244.0839.2.085',
#   'BOLSA FAMÍLIA (IGD SUAS, IGDBF E OUTROS)',
#   46318,
#   46376,
#   (['3.1.90.04.00', '500,00'],
#    ['3.1.90.11.00', '1.000,00'],
#    ['3.3.90.30.00', '80.000,00'],
#    ['3.3.90.32.00', '3.000,00'],
#    ['3.3.90.36.00', '5.000,00'],
#    ['3.3.90.39.00', '30.000,00'],
#    ['3.3.90.92.00', '100,00'])),
#  ('16.482.0839.1.027',
#   'CONSTR.REFORMA E AMPL.DE MORADIAS',
#   46540,
#   46591,
#   (['4.4.90.51.00', '10.000,00'], ['4.4.90.52.00', '2.000,00'])),
#  ('16.482.2839.9.057',
#   'DOAÇÃO MATERIAIS P/CONST.REF.AMP.MORADIA',
#   46647,
#   46705,
#   (['3.3.90.32.00', '4.000,00'],)),
#  ('26.122.1539.1.028',
#   'OBRAS,INSTAL.EQUIP.P/FUNDO MUN.TRÂNSITO',
#   47667,
#   47724,
#   (['4.4.90.51.00', '18.123,59'], ['4.4.90.52.00', '94.867,96'])),
#  ('26.122.1539.2.070',
#   'MANUT.ATIVIDADES DE FUNDO MUN.DE TRÂNSITO',
#   47782,
#   47841,
#   (['3.1.90.11.00', '3.000,00'],
#    ['3.3.90.14.00', '3.000,00'],
#    ['3.3.90.30.00', '220.000,00'],
#    ['3.3.90.34.00', '4.000,00'],
#    ['3.3.90.36.00', '12.000,00'],
#    ['3.3.90.39.00', '300.000,00'],
#    ['3.3.90.92.00', '100,00'])),
#  ('26.122.2839.9.058',
#   'ENCARGOS ESPECIAIS DO FUNDO DE TRÂNSITO',
#   48010,
#   48067,
#   (['3.1.90.13.00', '4.000,00'],
#    ['3.1.90.94.00', '500,00'],
#    ['3.1.91.13.00', '4.000,00'],
#    ['3.3.90.32.00', '1.000,00'],
#    ['3.3.90.93.00', '5.000,00'])),
#  ('04.122.0439.1.043',
#   'EQUIPAMENTOS PARA FDO PROCURADORES',
#   48707,
#   48759,
#   (['4.4.90.52.00', '2.000,00'],)),
#  ('04.122.0439.2.087',
#   'MATENÇÃO DAS ATIV. DO FDO. PROCURADORES',
#   48791,
#   48848,
#   (['3.3.90.14.00', '1.000,00'],
#    ['3.3.90.30.00', '4.000,00'],
#    ['3.3.90.36.00', '176.182,45'],
#    ['3.3.90.39.00', '2.000,00']))]

# %%
unidades_temp = []
for n in re.finditer(r'(?:CLASSIFICAÇÃO ORÇAMENTÁRIA\nVALORES\nDESPESA\nTOTAL\n)(.+)\n(.+)\n(.+)\n(.+)\n', text_global):
    unidades_temp.append([n.start(), n.end(), list(n.groups())])
    
unidades_temp.append([len(text_global),len(text_global),None])

# %%
unidades_temp[0]
# Out:
# [231, 329, ['CAMARA MUNICIPAL DE JATAI', 'CAMARA MUNICIPAL', '01', '01']]

# %%
unidades = []
for i in range(len(unidades_temp)-1):
    unidade = unidades_temp[i]
    x1 = unidades_temp[i][1]
    x2 = unidades_temp[i+1][0]
    
    unidade = [(unidade[2][2], unidade[2][0]), (unidade[2][3], unidade[2][1]), []]
    for aplic in aplicacoes:
        if aplic[2] >= x1 and aplic[3] <= x2:
            unidade[-1].append(aplic)    
    unidades.append(unidade)

# %%
unidades_temp = unidades
unidades = []

orgao = ''
unidade_orc = ''
for u in unidades_temp:
    if u[0] != orgao or u[1] != unidade_orc:
        orgao = u[0]
        unidade_orc = u[1]
        unidades.append([orgao, unidade_orc, []])
    unidades[-1][-1].extend(u[2])

# %%
unidades
# Out:
# [[('01', 'CAMARA MUNICIPAL DE JATAI'),
#   ('01', 'CAMARA MUNICIPAL'),
#   [('01.031.0139.1.001',
#     'OBRAS,INSTAL.EQUIP.CAMARA MUNICIPAL',
#     329,
#     382,
#     (['4.4.90.51.00', '218.196,31'], ['4.4.90.52.00', '603.360,24'])),
#    ('01.031.0139.2.001',
#     'MANUT.ATIV.DA CAMARA MUNICIPAL',
#     442,
#     490,
#     (['3.1.90.04.00', '9.486,80'],
#      ['3.1.90.11.00', '11.185.818,60'],
#      ['3.1.90.16.00', '18.973,59'],
#      ['3.1.90.92.00', '948,68'],
#      ['3.3.90.14.00', '137.558,55'],
#      ['3.3.90.30.00', '512.287,00'],
#      ['3.3.90.33.00', '6.640,76'],
#      ['3.3.90.34.00', '151.788,74'],
#      ['3.3.90.35.00', '47.433,98'],
#      ['3.3.90.36.00', '85.381,17'],
#      ['3.3.90.37.00', '9.486,80'],
#      ['3.3.90.39.00', '569.207,77'],
#      ['3.3.90.40.00', '100.000,00'],
#      ['3.3.90.92.00', '948,68'])),
#    ('01.271.2839.9.061',
#     'ENC.PREV.C/O REGIME GERAL DE PREVIDÊNCIA',
#     827,
#     885,
#     (['3.1.90.13.00', '958.267,07'],
#      ['3.1.90.54.00', '1.897,36'],
#      ['3.1.90.56.00', '1.897,36'],
#      ['3.1.90.58.00', '474,34'],
#      ['3.1.90.92.00', '474,34'])),
#    ('01.272.2839.9.001',
#     'ENC.PREV. C/O REGIME PRÓPRIO DE PREVIDÊNCIA',
#     1005,
#     1066,
#     (['3.1.90.01.00', '2.371,70'],
#      ['3.1.90.03.00', '2.371,70'],
#      ['3.1.91.13.00', '284.603,89'],
#      ['3.1.91.92.00', '1.897,36'],
#      ['3.3.90.05.00', '474,34'],
#      ['3.3.91.97.00', '1.423,02'])),
#    ('01.845.2839.9.002',
#     'TRANSFERÊNCIAS A INSTITUIÇÕES PRIVADAS',
#     1628,
#     1684,
#     (['3.3.50.41.00', '9.486,80'],)),
#    ('01.846.2839.9.003',
#     'OUTROS ENCARGOS ESPECIAIS DA CÂMARA',
#     1716,
#     1769,
#     (['3.1.90.91.00', '18.973,59'],
#      ['3.1.90.94.00', '47.433,98'],
#      ['3.2.90.21.00', '4.743,40'],
#      ['3.2.90.22.00', '948,68'],
#      ['3.2.90.91.00', '948,68'],
#      ['3.2.90.92.00', '948,68'],
#      ['3.3.90.91.00', '2.846,04']))]],
#  [('03', 'PREFEITURA MUNICIPAL DE JATAI'),
#   ('02', 'GABINETE DO PREFEITO'),
#   [('04.122.0439.1.029',
#     'BENS MÓVEIS P/O GABINETE DO PREFEITO',
#     2425,
#     2479,
#     (['4.4.90.52.00', '50.000,00'],)),
#    ('04.122.0439.2.002',
#     'MANUT.ATIV.SEC.EXECUTIVA GABINETE DO PREFEITO',
#     2513,
#     2576,
#     (['3.1.90.11.00', '1.300.000,00'],
#      ['3.3.90.14.00', '45.000,00'],
#      ['3.3.90.30.00', '30.000,00'],
#      ['3.3.90.33.00', '3.000,00'],
#      ['3.3.90.34.00', '10.000,00'],
#      ['3.3.90.36.00', '4.000,00'],
#      ['3.3.90.39.00', '100.000,00'],
#      ['3.3.90.92.00', '500,00'])),
#    ('04.122.0439.2.003',
#     'MANUT.ATIVIDADES DA PROCURADORIA GERAL',
#     2773,
#     2829,
#     (['3.1.90.11.00', '1.202.000,00'],
#      ['3.3.90.14.00', '4.743,40'],
#      ['3.3.90.30.00', '9.486,80'],
#      ['3.3.90.36.00', '4.743,40'],
#      ['3.3.90.39.00', '9.486,80'],
#      ['3.3.90.92.00', '948,68'])),
#    ('04.122.0439.2.004',
#     'DIVULG.PROP.PUBLIC.OFICIAIS E ATOS ADM',
#     2977,
#     3033,
#     (['3.3.90.30.00', '2.000,00'],
#      ['3.3.90.36.00', '2.000,00'],
#      ['3.3.90.39.00', '800.000,00'],
#      ['3.3.90.92.00', '500,00'])),
#    ('04.122.0439.2.005',
#     'MANUT.ATIV.DA OUVIDORIA GERAL DO MUNICÍPIO',
#     3133,
#     3193,
#     (['3.1.90.04.00', '500,00'],
#      ['3.1.90.11.00', '102.000,00'],
#      ['3.3.90.14.00', '1.000,00'],
#      ['3.3.90.30.00', '4.000,00'],
#      ['3.3.90.35.00', '1.000,00'],
#      ['3.3.90.36.00', '4.000,00'],
#      ['3.3.90.39.00', '4.000,00'],
#      ['3.3.90.92.00', '200,00'])),
#    ('04.122.0439.2.008',
#     'FESTIVIDADES, RECEPÇÕES E HOMENAGENS',
#     3804,
#     3858,
#     (['3.3.90.30.00', '75.000,00'],
#      ['3.3.90.36.00', '5.000,00'],
#      ['3.3.90.39.00', '200.000,00'])),
#    ('04.122.0839.2.046',
#     'MANUT.DEPART.PROGRAMAS E PROJETOS',
#     3939,
#     3990,
#     (['3.3.90.92.00', '948,68'],)),
#    ('04.124.0439.2.006',
#     'MANUT.ATIV.DA CONTROLADORIA GERAL DO MUNICÍPIO',
#     4018,
#     4082,
#     (['3.1.90.04.00', '400,00'],
#      ['3.1.90.11.00', '302.000,00'],
#      ['3.3.90.14.00', '1.500,00'],
#      ['3.3.90.30.00', '5.000,00'],
#      ['3.3.90.34.00', '3.000,00'],
#      ['3.3.90.36.00', '2.000,00'],
#      ['3.3.90.39.00', '2.000,00'],
#      ['3.3.90.92.00', '200,00'])),
#    ('04.846.2839.9.004',
#     'ENCARGOS ESP. DO GABINETE DO PREFEITO',
#     4268,
#     4323,
#     (['3.1.90.91.00', '10.000,00'], ['3.1.90.94.00', '20.000,00'])),
#    ('16.244.1639.1.002',
#     'OBRAS,INSTAL.EQUIP.SUPERINTEDÊNCIA DE HABITAÇÃO',
#     4380,
#     4445,
#     (['4.4.90.51.00', '164.735,92'],
#      ['4.4.90.52.00', '18.973,59'],
#      ['4.4.90.61.00', '9.486,80'])),
#    ('16.244.1639.2.010',
#     'MANUT.ATIV.SUPERINTENDÊNCIA DE HABITAÇÃO',
#     4526,
#     4584,
#     (['3.1.90.04.00', '300,00'],
#      ['3.1.90.11.00', '262.000,00'],
#      ['3.3.90.14.00', '1.500,00'],
#      ['3.3.90.30.00', '10.000,00'],
#      ['3.3.90.36.00', '5.000,00'],
#      ['3.3.90.39.00', '220.000,00'],
#      ['3.3.90.92.00', '500,00'])),
#    ('16.846.2839.9.005',
#     'ENCARGOS ESPECIAIS DA SUPER. DE HABITAÇÃO',
#     5174,
#     5233,
#     (['3.1.90.94.00', '8.000,00'], ['3.3.90.32.00', '5.000,00']))]],
#  [('03', 'PREFEITURA MUNICIPAL DE JATAI'),
#   ('03', 'SECRETARIA DE GESTÃO E PLANEJAMENTO'),
#   [('02.061.0239.1.031',
#     'BENS MÓVEIS P/O PODER JUDICIÁRIO E ELEITORAL',
#     5741,
#     5803,
#     (['4.4.90.52.00', '1.000,00'],)),
#    ('02.061.0239.2.011',
#     'ENCARGOS C/O PODER JUDICIÁRIO ELEITORAL',
#     5835,
#     5892,
#     (['3.3.90.30.00', '2.000,00'],
#      ['3.3.90.36.00', '2.000,00'],
#      ['3.3.90.39.00', '2.000,00'])),
#    ('04.122.0439.1.045',
#     'OBRAS,INSTAL.EQUIP.PRÉDIOS PÚBLICOS',
#     5968,
#     6021,
#     (['4.4.90.51.00', '1.576.532,65'],
#      ['4.4.90.52.00', '22.332,84'],
#      ['4.4.90.61.00', '336.640,76'])),
#    ('04.122.0439.2.012',
#     'MANUT.ATIV.DIVISÃO DE SERVIÇOS ADMINISTRATIVOS',
#     6108,
#     6172,
#     (['3.1.90.04.00', '500,00'],
#      ['3.1.90.11.00', '5.980.000,00'],
#      ['3.3.90.14.00', '35.000,00'],
#      ['3.3.90.30.00', '800.000,00'],
#      ['3.3.90.33.00', '1.000,00'],
#      ['3.3.90.34.00', '5.000,00'],
#      ['3.3.90.36.00', '150.000,00'],
#      ['3.3.90.39.00', '4.150.000,00'],
#      ['3.3.90.40.00', '400.000,00'],
#      ['3.3.90.92.00', '500,00'],
#      ['4.4.90.52.00', '40.000,00'])),
#    ('04.122.0439.2.013',
#     'MANUT.ATIV.DA DIVISÃO DE RECURSOS HUMANOS',
#     6441,
#     6500,
#     (['3.1.90.04.00', '500,00'],
#      ['3.1.90.11.00', '1.000,00'],
#      ['3.3.90.14.00', '1.500,00'],
#      ['3.3.90.30.00', '2.500,00'],
#      ['3.3.90.35.00', '5.000,00'],
#      ['3.3.90.36.00', '4.000,00'],
#      ['3.3.90.39.00', '3.000,00'],
#      ['3.3.90.92.00', '400,00'])),
#    ('04.122.0439.2.014',
#     'MANUT. DE PRÉDIOS PÚBLICOS DIVERSOS',
#     7122,
#     7175,
#     (['3.3.90.30.00', '420.000,00'],
#      ['3.3.90.36.00', '4.000,00'],
#      ['3.3.90.39.00', '525.000,00'],
#      ['3.3.90.92.00', '500,00'],
#      ['4.4.90.52.00', '40.000,00'])),
#    ('04.122.0439.2.017',
#     'MANUT.ATIV.DE DIVISÃO DE PLANEJAMENTO',
#     7300,
#     7355,
#     (['3.1.90.11.00', '1.000,00'],
#      ['3.3.90.14.00', '1.000,00'],
#      ['3.3.90.30.00', '40.000,00'],
#      ['3.3.90.36.00', '12.000,00'],
#      ['3.3.90.39.00', '16.000,00'])),
#    ('04.845.2839.9.008',
#     'TRANSFERÊNCIAS A INSTITUIÇÕES PRIVADAS',
#     7479,
#     7535,
#     (['3.3.50.43.00', '47.433,98'], ['3.3.60.41.00', '20.000,00'])),
#    ('04.846.2839.9.010',
#     'OUTROS ENCARGOS DA SEC.DE ADMINISTRAÇÃO',
#     7592,
#     7649,
#     (['3.1.90.91.00', '10.000,00'],
#      ['3.1.90.94.00', '60.000,00'],
#      ['3.3.90.10.00', '5.000,00'],
#      ['3.3.90.32.00', '5.000,00'])),
#    ('09.271.0939.9.006',
#     'ENC. PREV. C/O REGIME GERAL DE PREVIDÊNCIA',
#     7750,
#     7810,
#     (['3.1.90.13.00', '3.400.000,00'], ['3.1.90.92.00', '1.000,00'])),
#    ('09.272.0939.9.007',
#     'ENC.PREV.C/O REGIME PRÓPRIO DE PREVIDÊNCIA',
#     7872,
#     7932,
#     (['3.1.90.03.00', '120.000,00'],
#      ['3.1.91.13.00', '2.800.000,00'],
#      ['3.3.91.97.00', '1.650.000,00'])),
#    ('26.122.2639.1.004',
#     'OBRAS,INSTAL.EQUIP. P/O TRANSPORTE MUNICIPAL',
#     8022,
#     8084,
#     (['4.4.90.51.00', '28.460,39'], ['4.4.90.52.00', '28.460,39'])),
#    ('26.122.2639.2.016',
#     'MANUT.DIVISÃO DE VEÍCULOS, MAQUIN.E EQUIPAMENTOS',
#     8141,
#     8207,
#     (['3.1.90.04.00', '400,00'],
#      ['3.1.90.11.00', '1.000,00'],
#      ['3.3.90.14.00', '1.000,00'],
#      ['3.3.90.30.00', '3.100.000,00'],
#      ['3.3.90.36.00', '15.000,00'],
#      ['3.3.90.39.00', '600.000,00'],
#      ['3.3.90.92.00', '500,00'])),
#    ('26.846.2839.9.012',
#     'OUTROS ENCARGOS DO SETOR DE TRANSPORTES',
#     8824,
#     8881,
#     (['3.1.90.91.00', '1.500,00'], ['3.1.90.94.00', '5.000,00']))]],
#  [('03', 'PREFEITURA MUNICIPAL DE JATAI'),
#   ('06', 'SECRETARIA DA FAZENDA'),
#   [('04.123.0439.1.034',
#     'BENS MÓVEIS P/ SECRETARIA DA FAZENDA',
#     9390,
#     9444,
#     (['4.4.90.52.00', '40.000,00'],)),
#    ('04.123.0439.2.019',
#     'MANUT.ATIV.DA SECRETARIA DA FAZENDA',
#     9478,
#     9531,
#     (['3.1.90.11.00', '3.030.000,00'],
#      ['3.3.90.14.00', '5.000,00'],
#      ['3.3.90.30.00', '1.000,00'],
#      ['3.3.90.34.00', '500,00'],
#      ['3.3.90.35.00', '4.500,00'],
#      ['3.3.90.36.00', '50.000,00'],
#      ['3.3.90.39.00', '950.000,00'],
#      ['3.3.90.40.00', '300.000,00'],
#      ['3.3.90.92.00', '500,00'])),
#    ('04.123.0439.2.020',
#     'MANUT.ATIVIDADES DA DIVISÃO DE COMPRAS',
#     9748,
#     9804,
#     (['3.1.90.11.00', '1.000,00'],
#      ['3.3.90.14.00', '1.000,00'],
#      ['3.3.90.30.00', '5.000,00'],
#      ['3.3.90.36.00', '2.000,00'],
#      ['3.3.90.39.00', '5.000,00'],
#      ['3.3.90.92.00', '400,00'])),
#    ('04.123.0439.2.021',
#     'MANUT.ATIV.DIVISÃO DE CONTABILIDADE',
#     9945,
#     9998,
#     (['3.1.90.11.00', '1.000,00'],
#      ['3.3.90.14.00', '500,00'],
#      ['3.3.90.30.00', '1.000,00'],
#      ['3.3.90.34.00', '500.000,00'],
#      ['3.3.90.36.00', '2.000,00'],
#      ['3.3.90.39.00', '50.000,00'],
#      ['3.3.90.92.00', '500,00'])),
#    ('28.843.2839.9.015',
#     'ENCARGOS C/A DÍVIDA INTERNA DO MUNICÍPIO',
#     10163,
#     10221,
#     (['4.6.90.71.00', '3.000.000,00'],
#      ['4.6.90.73.00', '500,00'],
#      ['4.6.90.75.00', '500,00'],
#      ['4.6.91.71.00', '4.500.000,00'])),
#    ('28.846.2839.9.011',
#     'CONTRIBUIÇÕES PARA O PASEP',
#     10752,
#     10796,
#     (['3.3.90.47.00', '2.800.000,00'],)),
#    ('28.846.2839.9.016',
#     'OUTROS ENCARGOS C/A DÍVIDA DO MUNICÍPIO',
#     10836,
#     10893,
#     (['3.1.90.91.00', '400.000,00'],
#      ['3.1.90.94.00', '10.000,00'],
#      ['3.2.90.21.00', '2.320.000,00'],
#      ['3.2.90.22.00', '1.000.000,00'],
#      ['3.2.90.25.00', '10.000,00'],
#      ['3.3.90.10.00', '500,00'],
#      ['3.3.90.31.00', '20.000,00'],
#      ['3.3.90.91.00', '250.000,00'],
#      ['3.3.90.93.00', '200.000,00']))]],
#  [('03', 'PREFEITURA MUNICIPAL DE JATAI'),
#   ('08', 'SECRETARIA DE EDUCACAO'),
#   [('12.306.1239.2.026',
#     'MANUT.ATIV.DA MERENDA ESCOLAR',
#     11563,
#     11610,
#     (['3.3.90.30.00', '3.750.000,00'],)),
#    ('12.361.1239.1.005',
#     'OBRAS,INSTAL.EQUIP.ENSINO FUNDAMENTAL',
#     11650,
#     11705,
#     (['4.4.90.51.00', '3.010.657,70'], ['4.4.90.52.00', '730.483,31'])),
#    ('12.361.1239.2.027',
#     'MANUT.DIVISÃO ADIMINIST.SEC. DE EDUCAÇÃO',
#     11769,
#     11827,
#     (['3.1.90.04.00', '6.000.000,00'],
#      ['3.1.90.11.00', '2.200.000,00'],
#      ['3.3.90.14.00', '5.000,00'],
#      ['3.3.90.30.00', '390.000,00'],
#      ['3.3.90.33.00', '1.000,00'],
#      ['3.3.90.34.00', '90.000,00'],
#      ['3.3.90.35.00', '500,00'],
#      ['3.3.90.36.00', '10.000,00'],
#      ['3.3.90.39.00', '1.350.000,00'],
#      ['3.3.90.40.00', '80.000,00'],
#      ['3.3.90.92.00', '500,00'])),
#    ('12.361.1239.2.028',
#     'MANUTENÇÃO DO ENSINO FUNDAMENTAL',
#     12097,
#     12147,
#     (['3.1.90.04.00', '200.000,00'],
#      ['3.1.90.11.00', '1.000.000,00'],
#      ['3.3.90.14.00', '2.000,00'],
#      ['3.3.90.30.00', '400.000,00'],
#      ['3.3.90.36.00', '10.000,00'],
#      ['3.3.90.39.00', '50.000,00'],
#      ['3.3.90.92.00', '200,00'])),
#    ('12.361.1239.2.029',
#     'ENCARGOS COM O TRANSPORTE ESCOLAR',
#     12323,
#     12374,
#     (['3.3.90.30.00', '10.000,00'],
#      ['3.3.90.36.00', '20.000,00'],
#      ['3.3.90.39.00', '9.000.000,00'],
#      ['3.3.90.92.00', '300,00'])),
#    ('12.361.1239.2.030',
#     'MANUT.ATIV.DIV. DE HIGIENE E ALIMENTAÇÃO',
#     12865,
#     12923,
#     (['3.1.90.04.00', '500.000,00'],
#      ['3.1.90.11.00', '4.400.000,00'],
#      ['3.3.90.14.00', '1.000,00'],
#      ['3.3.90.30.00', '20.000,00'],
#      ['3.3.90.34.00', '500,00'],
#      ['3.3.90.36.00', '4.000,00'],
#      ['3.3.90.39.00', '10.000,00'],
#      ['3.3.90.92.00', '400,00'])),
#    ('12.361.2839.9.017',
#     'ENCARGOS ESP. C/DESENVOLVIMENTO DO ENSINO',
#     13117,
#     13176,
#     (['3.1.90.13.00', '1.800.000,00'],
#      ['3.1.90.91.00', '500,00'],
#      ['3.1.90.94.00', '150.000,00'],
#      ['3.1.91.13.00', '2.100.000,00'],
#      ['3.2.90.22.00', '1.000,00'],
#      ['3.3.50.43.00', '1.000,00'],
#      ['3.3.60.41.00', '5.000,00'],
#      ['3.3.90.10.00', '400,00'],
#      ['3.3.90.18.00', '5.000,00'],
#      ['3.3.90.32.00', '2.000,00'],
#      ['3.3.90.91.00', '4.000,00'],
#      ['3.3.90.93.00', '14.230,19'],
#      ['3.3.91.97.00', '1.200.000,00'],
#      ['4.4.30.41.00', '2.000,00'],
#      ['4.6.90.71.00', '3.000,00'],
#      ['4.6.91.71.00', '5.000,00'])),
#    ('12.364.1239.2.032',
#     'ENCARGOS COM ENSINO SUPERIOR',
#     13553,
#     13599,
#     (['3.1.90.11.00', '650.000,00'],
#      ['3.3.90.30.00', '2.000,00'],
#      ['3.3.90.36.00', '2.000,00'],
#      ['3.3.90.39.00', '140.000,00'])),
#    ('12.364.2839.9.018',
#     'ENCARGOS ESPECIAIS C/O ENSINO SUPERIOR',
#     14117,
#     14173,
#     (['3.1.90.13.00', '1.000,00'],
#      ['3.1.91.13.00', '130.000,00'],
#      ['3.3.90.18.00', '1.000,00'],
#      ['3.3.90.32.00', '1.000,00'],
#      ['3.3.91.97.00', '70.000,00'])),
#    ('12.364.2839.9.059',
#     'TRANSFERÊNCIAS DE RECURSOS A UEG',
#     14298,
#     14348,
#     (['4.4.30.41.00', '10.000,00'],)),
#    ('12.364.2839.9.060',
#     'TRANSFERÊNCIAS DE RECURSOS A UFG',
#     14382,
#     14432,
#     (['4.4.20.41.00', '10.000,00'],)),
#    ('12.365.1239.1.007',
#     'OBRAS,INSTAL.EQUIP.P/ENSINO INFANTIL',
#     14466,
#     14520,
#     (['4.4.90.51.00', '341.158,95'], ['4.4.90.52.00', '150.000,00'])),
#    ('12.365.1239.2.033',
#     'MANUTENÇÃO DO ENSINO INFANTIL',
#     14580,
#     14627,
#     (['3.1.90.04.00', '30.000,00'],
#      ['3.1.90.11.00', '6.931.000,00'],
#      ['3.3.90.14.00', '2.000,00'],
#      ['3.3.90.30.00', '350.000,00'],
#      ['3.3.90.36.00', '3.000,00'],
#      ['3.3.90.39.00', '70.000,00'])),
#    ('12.365.2839.9.019',
#     'ENCARGOS ESPECIAIS C/ ENSINO INFANTIL',
#     14781,
#     14836,
#     (['3.1.90.94.00', '30.000,00'], ['3.3.90.32.00', '1.500,00'])),
#    ('12.366.1239.2.034',
#     'ENCARGOS C/EDUCAÇÃO JOVENS E ADULTOS',
#     14892,
#     14946,
#     (['3.1.90.04.00', '500,00'],
#      ['3.1.90.11.00', '5.000,00'],
#      ['3.1.90.16.00', '500,00'],
#      ['3.1.90.92.00', '400,00'],
#      ['3.3.90.30.00', '5.000,00'],
#      ['3.3.90.36.00', '2.000,00'],
#      ['3.3.90.39.00', '4.000,00'],
#      ['3.3.90.92.00', '400,00'])),
#    ('12.366.2839.9.020',
#     'FÉRIAS, INDENIZAÇÕES E REST. TRABALHISTAS - EJA',
#     15547,
#     15612,
#     (['3.1.90.94.00', '400,00'],)),
#    ('12.367.1239.2.035',
#     'ENCARGOS C/EDUCAÇÃO ESPECIAL',
#     15640,
#     15686,
#     (['3.1.90.04.00', '474,34'],
#      ['3.1.90.11.00', '4.743,40'],
#      ['3.1.90.16.00', '474,34'],
#      ['3.1.90.92.00', '474,34'],
#      ['3.3.90.30.00', '5.692,08'],
#      ['3.3.90.36.00', '4.743,40'],
#      ['3.3.90.39.00', '4.743,40'],
#      ['3.3.90.92.00', '474,34'])),
#    ('12.367.2839.9.021',
#     'FÉRIAS, INDENIZAÇÕES E REST. TRABALHISTAS',
#     15865,
#     15924,
#     (['3.1.90.94.00', '4.743,40'],))]],
#  [('03', 'PREFEITURA MUNICIPAL DE JATAI'),
#   ('09', 'SECRETARIA DE ESPORTES E TURISMO'),
#   [('23.695.2339.1.013',
#     'OBRAS,INSTAL.EQUIP.DO POLO TURÍSTICO',
#     16410,
#     16464,
#     (['4.4.90.51.00', '40.000,00'], ['4.4.90.52.00', '20.000,00'])),
#    ('27.122.2739.1.008',
#     'OBRAS,INSTAL.EQUIP.DO DESPORTO E TURISMO',
#     16521,
#     16579,
#     (['4.4.90.51.00', '939.485,93'], ['4.4.90.52.00', '94.867,96'])),
#    ('27.122.2739.2.036',
#     'MANUT. SEC. ESPORTE E TURISMO',
#     16640,
#     16687,
#     (['3.1.90.11.00', '1.225.000,00'],
#      ['3.3.90.14.00', '13.000,00'],
#      ['3.3.90.30.00', '55.000,00'],
#      ['3.3.90.36.00', '25.000,00'],
#      ['3.3.90.39.00', '522.301,94'],
#      ['3.3.90.92.00', '900,00'])),
#    ('28.845.2839.9.022',
#     'TRANSFERÊNCIAS P/ APOIO AO DESPORTO E TURISMO',
#     16840,
#     16903,
#     (['3.3.50.41.00', '555.000,00'], ['3.3.50.43.00', '20.000,00'])),
#    ('28.845.2839.9.039',
#     'TRANSFERÊNCIAS A INSTITUIÇÕES PRIVADAS',
#     16962,
#     17018,
#     (['3.3.50.43.00', '20.000,00'], ['3.3.50.45.00', '120.000,00'])),
#    ('28.846.2839.9.023',
#     'ENCARGOS ESPECIAIS C/ DESPORTO E TURISMO',
#     17077,
#     17135,
#     (['3.1.90.94.00', '11.897,36'],
#      ['3.3.90.31.00', '10.000,00'],
#      ['3.3.90.32.00', '9.743,40'],
#      ['3.3.90.48.00', '60.000,00']))]],
#  [('03', 'PREFEITURA MUNICIPAL DE JATAI'),
#   ('10', 'SECRETARIA DA CULTURA'),
#   [('13.392.1339.1.009',
#     'OBR.INSTAL.EQUIP.DE DIFUSÃO CULTURAL',
#     17689,
#     17743,
#     (['4.4.90.51.00', '33.203,79'], ['4.4.90.52.00', '52.690,58'])),
#    ('13.392.1339.2.038',
#     'ENCARGOS C/A DIFUSÃO CULTURAL',
#     17800,
#     17847,
#     (['3.1.90.11.00', '850.000,00'],
#      ['3.3.90.14.00', '1.000,00'],
#      ['3.3.90.30.00', '15.000,00'],
#      ['3.3.90.34.00', '500,00'],
#      ['3.3.90.36.00', '20.000,00'],
#      ['3.3.90.39.00', '20.000,00'],
#      ['3.3.90.92.00', '400,00'])),
#    ('28.845.2839.9.024',
#     'TRANSFERÊNCIAS A INSTITUIÇÕES PRIVADAS',
#     18014,
#     18070,
#     (['3.3.50.41.00', '20.000,00'], ['3.3.50.43.00', '20.000,00'])),
#    ('28.846.2839.9.025',
#     'OUTROS ENCARGOS DA SECRETARIA DE CULTURA',
#     18127,
#     18185,
#     (['3.1.90.94.00', '15.000,00'],
#      ['3.3.90.10.00', '20.000,00'],
#      ['3.3.90.31.00', '30.000,00'],
#      ['3.3.90.32.00', '5.000,00'],
#      ['3.3.90.48.00', '15.000,00']))]],
#  [('03', 'PREFEITURA MUNICIPAL DE JATAI'),
#   ('11', 'SECRETARIA DE OBRAS E PLANEJAMENTO URBANO'),
#   [('15.451.1539.1.010',
#     'OBRAS DE INFRA-ESTRUT.MELHORIAS URBANAS',
#     18771,
#     18828,
#     (['4.4.90.51.00', '14.584.600,70'],)),
#    ('15.451.1539.1.035',
#     'BENS MÓVEIS P/A SEC.DE OBRAS E PLAN.URBANO',
#     18870,
#     18930,
#     (['4.4.90.52.00', '15.000,00'],)),
#    ('15.451.1539.2.039',
#     'MANUT.ATIV.DIVISÃO DE OBRAS E PLAN. URBANO',
#     18964,
#     19024,
#     (['3.1.90.04.00', '500,00'],
#      ['3.1.90.11.00', '5.200.000,00'],
#      ['3.3.90.14.00', '3.000,00'],
#      ['3.3.90.30.00', '300.000,00'],
#      ['3.3.90.36.00', '150.000,00'],
#      ['3.3.90.37.00', '4.000,00'],
#      ['3.3.90.39.00', '400.000,00'],
#      ['3.3.90.92.00', '500,00'])),
#    ('15.451.1539.2.041',
#     'MANUT.DIVISÃO DE VIAS PÚBLICAS',
#     19220,
#     19268,
#     (['3.1.90.04.00', '400,00'],
#      ['3.1.90.11.00', '2.000,00'],
#      ['3.3.90.30.00', '1.375.637,77'],
#      ['3.3.90.36.00', '10.000,00'],
#      ['3.3.90.39.00', '80.000,00'],
#      ['3.3.90.92.00', '500,00'])),
#    ('15.846.2839.9.026',
#     'FÉRIAS, INDENIZAÇÕES E REST. TRABALHISTAS',
#     19416,
#     19475,
#     (['3.1.90.94.00', '120.000,00'],)),
#    ('26.781.2639.1.040',
#     'OBRAS DO AEROPORTO DE CARGAS E PASSAG.DE JATAÍ',
#     19511,
#     19575,
#     (['4.4.90.51.00', '2.381.962,03'],
#      ['4.4.90.52.00', '47.433,98'],
#      ['4.4.90.61.00', '28.460,39']))]],
#  [('03', 'PREFEITURA MUNICIPAL DE JATAI'),
#   ('15', 'SECRETARIA DE DESENVOLVIMENTO SOCIAL E CIDADANIA'),
#   [('08.122.0839.1.015',
#     'OBRAS,INSTAL.EQUIP.ASSIST.SOCIAL GERAL',
#     20150,
#     20206,
#     (['4.4.90.51.00', '123.328,35'],
#      ['4.4.90.52.00', '58.818,14'],
#      ['4.4.90.61.00', '18.973,59'])),
#    ('08.122.0839.2.045',
#     'MANUT.DIVISÃO PROM.ASSISTÊNCIA SOCIAL',
#     20288,
#     20343,
#     (['3.1.90.04.00', '210.000,00'],
#      ['3.1.90.11.00', '3.100.000,00'],
#      ['3.3.90.14.00', '1.000,00'],
#      ['3.3.90.30.00', '5.000,00'],
#      ['3.3.90.33.00', '2.000,00'],
#      ['3.3.90.36.00', '44.743,40'],
#      ['3.3.90.39.00', '309.486,80'],
#      ['3.3.90.92.00', '974,34'])),
#    ('08.243.0839.2.075',
#     'MANUTENÇÃO DAS ATIV. DO CONSELHO TUTELAR',
#     20540,
#     20598,
#     (['3.1.90.11.00', '202.000,00'],
#      ['3.3.90.14.00', '1.000,00'],
#      ['3.3.90.30.00', '1.000,00'],
#      ['3.3.90.36.00', '1.000,00'],
#      ['3.3.90.39.00', '3.000,00'],
#      ['3.3.90.92.00', '100,00'])),
#    ('08.845.2839.9.030',
#     'TRANSFERÊNCIAS A INSTITUIÇÕES PRIVADAS',
#     20742,
#     20798,
#     (['3.3.50.43.00', '3.055.000,00'], ['3.3.60.41.00', '20.000,00'])),
#    ('08.846.2839.9.031',
#     'OUTROS ENC.ESP.DA SEC.DESENVOL. SOCIAL',
#     20861,
#     20917,
#     (['3.1.90.91.00', '1.000,00'],
#      ['3.1.90.94.00', '40.000,00'],
#      ['3.3.90.31.00', '1.000,00'],
#      ['3.3.90.32.00', '2.000,00'],
#      ['3.3.90.46.00', '500,00'],
#      ['3.3.90.48.00', '1.000,00'],
#      ['3.3.90.49.00', '1.000,00'],
#      ['3.3.90.91.00', '5.000,00'],
#      ['3.3.90.93.00', '5.000,00'])),
#    ('16.244.1639.1.016',
#     'OBRAS,INSTAL.EQUIP.PARA HABITAÇÕES POPULARES',
#     21575,
#     21637,
#     (['4.4.90.51.00', '350.000,00'],
#      ['4.4.90.52.00', '37.947,18'],
#      ['4.4.90.61.00', '14.230,19']))]],
#  [('03', 'PREFEITURA MUNICIPAL DE JATAI'),
#   ('16', 'SECRETARIA DO DESENVOLVIMENTO RURAL'),
#   [('20.122.2039.1.017',
#     'OBRAS,INSTAL.EQUIP.AGRICULT.E PECUÁRIA',
#     22201,
#     22257,
#     (['4.4.90.51.00', '55.504,11'],
#      ['4.4.90.52.00', '673.562,53'],
#      ['4.4.90.61.00', '9.486,80'])),
#    ('20.606.2039.2.050',
#     'MANUT. DA SEC. DO DESENV. RURAL',
#     22338,
#     22387,
#     (['3.1.90.11.00', '1.900.000,00'],
#      ['3.3.90.14.00', '4.000,00'],
#      ['3.3.90.30.00', '140.000,00'],
#      ['3.3.90.36.00', '105.000,00'],
#      ['3.3.90.39.00', '140.000,00'],
#      ['3.3.90.92.00', '800,00'])),
#    ('28.845.2839.9.033',
#     'TRANSFERÊNCIAS A INSTITUIÇÕES PRIVADAS',
#     22541,
#     22597,
#     (['3.3.50.43.00', '10.000,00'], ['3.3.60.41.00', '410.000,00'])),
#    ('28.846.2839.9.034',
#     'ENCAR. ESP.DA SEC. AGRICULTURA E PECUÁRIA',
#     22656,
#     22715,
#     (['3.1.90.94.00', '15.000,00'],
#      ['3.3.90.91.00', '500,00'],
#      ['4.4.30.42.00', '2.000,00']))]],
#  [('03', 'PREFEITURA MUNICIPAL DE JATAI'),
#   ('31', 'SECRETARIA DO MEIO AMBIENTE E SERVIÇOS URBANOS'),
#   [('15.452.1539.1.018',
#     'OBRAS,INSTAL.EQUIP.SERVIÇOS URBANOS',
#     23271,
#     23324,
#     (['4.4.90.51.00', '1.337.638,27'],
#      ['4.4.90.52.00', '66.407,57'],
#      ['4.4.90.61.00', '47.433,98'])),
#    ('15.452.1539.2.052',
#     'MANUT.SEC.MEIO AMB. E SERVIÇOS URBANOS',
#     23410,
#     23466,
#     (['3.1.90.04.00', '500,00'],
#      ['3.1.90.11.00', '5.200.000,00'],
#      ['3.3.90.14.00', '15.000,00'],
#      ['3.3.90.30.00', '470.000,00'],
#      ['3.3.90.35.00', '500,00'],
#      ['3.3.90.36.00', '260.000,00'],
#      ['3.3.90.37.00', '2.000,00'],
#      ['3.3.90.39.00', '939.993,58'],
#      ['3.3.90.92.00', '1.000,00'])),
#    ('15.452.1539.2.054',
#     'MANUT.DEPART.COLETA DE LIXO DOMICILIAR',
#     23685,
#     23741,
#     (['3.3.90.30.00', '10.000,00'],
#      ['3.3.90.36.00', '10.000,00'],
#      ['3.3.90.39.00', '7.970.000,00'])),
#    ('15.452.1539.2.056',
#     'MANUT. DE PRAÇAS, PARQUES E JARDINS',
#     23827,
#     23880,
#     (['3.1.90.11.00', '1.000,00'],
#      ['3.3.90.30.00', '25.000,00'],
#      ['3.3.90.36.00', '15.000,00'],
#      ['3.3.90.39.00', '270.000,00'],
#      ['4.4.90.52.00', '30.000,00'])),
#    ('17.512.1739.1.011',
#     'OBRAS E EQUIP.SANEAMENTO BÁSICO URBANO',
#     24007,
#     24063,
#     (['4.4.90.51.00', '113.841,55'],
#      ['4.4.90.52.00', '9.486,80'],
#      ['4.4.90.61.00', '47.433,98'])),
#    ('17.512.1739.1.036',
#     'OBRAS CONSÓRCIO INTERM.RESÍDUOS SÓLIDOS',
#     24144,
#     24201,
#     (['4.4.71.70.00', '10.000,00'],)),
#    ('17.512.1739.2.071',
#     'MANUT.CONSÓRCIO INTERM.RESÍDUOS SÓLIDOS',
#     24235,
#     24292,
#     (['3.1.71.70.00', '14.230,19'], ['3.3.71.70.00', '14.230,19'])),
#    ('17.845.2839.9.027',
#     'TRANSF.CONSÓRCIO INTERM.RESÍDUOS SÓLIDOS',
#     24798,
#     24856,
#     (['3.3.71.43.00', '5.000,00'],)),
#    ('18.122.1839.1.014',
#     'OBRAS,INSTAL.EQUIP.GESTÃO AMBIENTAL',
#     24888,
#     24941,
#     (['4.4.90.51.00', '340.000,52'],
#      ['4.4.90.52.00', '18.973,59'],
#      ['4.4.90.61.00', '9.486,80'])),
#    ('25.122.1539.1.039',
#     'BENS MÓVEIS P/ILUMINAÇÃO PÚBLICA',
#     25022,
#     25072,
#     (['4.4.90.52.00', '5.000,00'],)),
#    ('25.122.1539.2.055',
#     'MANUT.DEPARTAMENTO DE ILUMINAÇÃO PÚBLICA',
#     25104,
#     25162,
#     (['3.1.90.11.00', '130.000,00'],
#      ['3.3.90.14.00', '1.000,00'],
#      ['3.3.90.30.00', '343.720,22'],
#      ['3.3.90.36.00', '10.000,00'],
#      ['3.3.90.37.00', '500,00'],
#      ['3.3.90.39.00', '4.395.000,00'],
#      ['3.3.90.92.00', '200,00'])),
#    ('28.122.2839.9.029',
#     'ENCARGOS ESPECIAIS DA SEC. MEIO AMB. SERV. URBANOS',
#     25335,
#     25403,
#     (['3.1.90.94.00', '45.000,00'],
#      ['3.3.50.43.00', '20.000,00'],
#      ['3.3.90.91.00', '400,00']))]],
#  [('03', 'PREFEITURA MUNICIPAL DE JATAI'),
#   ('32', 'SECRETARIA DE DESENVOLVIMENTO ECONOMICO'),
#   [('19.573.1939.1.037',
#     'OBRAS,INSTAL.EQUIP.P/ SEC. DESENV. ECONÔMICO',
#     25965,
#     26027,
#     (['4.4.90.51.00', '56.920,78'], ['4.4.90.52.00', '9.486,80'])),
#    ('19.573.1939.2.072',
#     'MANUT. DA SUP. DE CIÊNCIA, TECNOL. E INOVAÇÃO',
#     26083,
#     26146,
#     (['3.3.90.14.00', '3.000,00'],
#      ['3.3.90.30.00', '3.000,00'],
#      ['3.3.90.36.00', '25.000,00'],
#      ['3.3.90.39.00', '10.000,00'],
#      ['3.3.90.92.00', '400,00'])),
#    ('22.661.2239.1.012',
#     'OBRAS,INSTAL.EQUIP.DIST.INDUSTRIAL',
#     26267,
#     26319,
#     (['4.4.90.51.00', '72.301,94'],
#      ['4.4.90.52.00', '23.716,99'],
#      ['4.4.90.61.00', '37.947,18'])),
#    ('22.661.2239.2.042',
#     'MANUT.ATIV.DA SEC. DESENVOLVIMENTO ECONÔMICO',
#     26400,
#     26462,
#     (['3.1.90.11.00', '630.000,00'],
#      ['3.3.90.14.00', '2.500,00'],
#      ['3.3.90.30.00', '20.000,00'],
#      ['3.3.90.36.00', '10.000,00'],
#      ['3.3.90.39.00', '20.000,00'],
#      ['3.3.90.92.00', '500,00'])),
#    ('28.845.2839.9.037',
#     'TRANSFERÊNCIAS A INSTITUIÇÕES PRIVADAS',
#     26609,
#     26665,
#     (['3.3.50.41.00', '20.000,00'],)),
#    ('28.846.2839.9.028',
#     'ENCARGOS ESP.COM SEC. DESENVOLVIMENTO ECONÔMICO',
#     26699,
#     26764,
#     (['3.1.90.94.00', '10.000,00'],
#      ['3.3.90.18.00', '2.000,00'],
#      ['3.3.90.20.00', '5.000,00'],
#      ['3.3.90.31.00', '2.000,00'])),
#    ('28.846.2839.9.038',
#     'FÉRIAS, INDENIZAÇÕES E REST. TRABALHISTAS',
#     26864,
#     26923,
#     (['3.1.90.94.00', '10.000,00'],))]],
#  [('03', 'PREFEITURA MUNICIPAL DE JATAI'),
#   ('34', 'FUNDO MUNICIPAL DE CULTURA'),
#   [('13.392.1339.1.041',
#     'OBRAS,INSTAL. E EQUIP. P/O FUNDO DE CULTURA',
#     27419,
#     27480,
#     (['4.4.90.51.00', '273.716,99'], ['4.4.90.52.00', '18.973,59'])),
#    ('13.392.1339.2.074',
#     'MANUTENÇÃO DAS ATIV. DO FUNDO DE CULTURA',
#     27539,
#     27597,
#     (['3.1.90.11.00', '2.000,00'],
#      ['3.3.90.14.00', '500,00'],
#      ['3.3.90.30.00', '10.000,00'],
#      ['3.3.90.36.00', '10.000,00'],
#      ['3.3.90.39.00', '10.000,00'],
#      ['3.3.90.92.00', '200,00'])),
#    ('28.845.2839.9.043',
#     'TRANSFERÊNCIAS A INSTITUIÇÕES PRIVADAS',
#     27739,
#     27795,
#     (['3.3.50.43.00', '20.000,00'], ['3.3.60.41.00', '5.000,00'])),
#    ('28.846.2839.9.044',
#     'ENCARGOS ESPECIAIS DO FUNDO DE CULTURA',
#     27851,
#     27907,
#     (['3.1.90.94.00', '2.000,00'],
#      ['3.3.90.10.00', '102.000,00'],
#      ['3.3.90.31.00', '2.000,00'],
#      ['3.3.90.32.00', '2.000,00']))]],
#  [('03', 'PREFEITURA MUNICIPAL DE JATAI'),
#   ('35', 'SECRETARIA DE SEGURANÇA PÚBLICA E DEFESA SOCIAL'),
#   [('06.181.0639.1.032',
#     'BENS MÓVEIS P/ SEC.SEG.PUBLICA, SUP.DE TRANSITO, E PROCON',
#     28479,
#     28554,
#     (['4.4.90.52.00', '44.199,31'],)),
#    ('06.181.0639.2.015',
#     'MANUT. SEC.SEG.PUBLICA, SUP.DE TRANSITO, E PROCON',
#     28588,
#     28655,
#     (['3.1.90.04.00', '900,00'],
#      ['3.1.90.11.00', '3.630.000,00'],
#      ['3.1.90.94.00', '8.000,00'],
#      ['3.3.90.14.00', '5.000,00'],
#      ['3.3.90.30.00', '85.000,00'],
#      ['3.3.90.34.00', '10.000,00'],
#      ['3.3.90.36.00', '65.000,00'],
#      ['3.3.90.39.00', '520.000,00'],
#      ['3.3.90.92.00', '900,00'],
#      ['3.3.90.93.00', '400.000,00']))]],
#  [('03', 'PREFEITURA MUNICIPAL DE JATAI'),
#   ('99', 'RESERVA DE CONTINGENCIA'),
#   [('99.999.9999.9.999',
#     'RESERVA DE CONTIGENCIA',
#     29365,
#     29405,
#     (['9.9.99.99.99', '830.094,67'],))]],
#  [('04', 'FUNDEB - JATAI'),
#   ('22', 'FUNDO DE GESTÃO DE RECURSOS DO FUNDEB'),
#   [('12.361.1239.2.057',
#     'MANUT.DAS ATIVIDADES DO FUNDEB - 60%',
#     29948,
#     30002,
#     (['3.1.90.04.00', '500,00'], ['3.1.90.11.00', '22.841.367,00'])),
#    ('12.361.1239.2.058',
#     'MANUT.DAS ATIVIDADES DO FUNDEB - 40%',
#     30064,
#     30118,
#     (['3.1.90.04.00', '500,00'],
#      ['3.1.90.11.00', '4.400.000,00'],
#      ['3.3.90.14.00', '1.000,00'],
#      ['3.3.90.30.00', '3.000,00'],
#      ['3.3.90.36.00', '2.000,00'],
#      ['3.3.90.39.00', '3.000,00'])),
#    ('12.361.2839.9.045',
#     'ENCARGOS ESPECIAIS DO FUNDEB - 60%',
#     30266,
#     30318,
#     (['3.1.90.13.00', '2.000,00'],
#      ['3.1.90.91.00', '2.000,00'],
#      ['3.1.90.94.00', '200.000,00'],
#      ['3.1.91.13.00', '2.200.000,00'],
#      ['3.3.91.97.00', '1.500.000,00'])),
#    ('12.361.2839.9.046',
#     'ENCARGOS ESPECIAIS DO FUNDEB - 40%',
#     30452,
#     30504,
#     (['3.1.90.13.00', '5.000,00'],
#      ['3.1.90.91.00', '1.000,00'],
#      ['3.1.90.94.00', '30.000,00'],
#      ['3.1.91.13.00', '500.000,00'],
#      ['3.3.90.91.00', '1.000,00'],
#      ['3.3.91.97.00', '300.000,00'])),
#    ('12.365.1239.2.059',
#     'MANUT.ATIV. DO ENSINO INFANTIL - 60%',
#     30653,
#     30707,
#     (['3.1.90.04.00', '500,00'],
#      ['3.1.90.11.00', '5.000.000,00'],
#      ['3.1.90.94.00', '50.000,00'],
#      ['3.1.91.13.00', '1.300.000,00'],
#      ['3.3.91.97.00', '1.000.000,00'])),
#    ('12.365.1239.2.060',
#     'MANUT.ATIV. DO ENSINO INFANTIL - 40%',
#     30842,
#     30896,
#     (['3.1.90.04.00', '200,00'],
#      ['3.1.90.11.00', '500.000,00'],
#      ['3.1.90.94.00', '20.000,00'],
#      ['3.1.91.13.00', '250.000,00'],
#      ['3.3.91.97.00', '150.000,00']))]],
#  [('05', 'FUNDACAO EDUCACIONAL DE JATAI'),
#   ('21', 'FUNDAÇÃO EDUCACIONAL DE JATAI'),
#   [('12.364.1239.1.020',
#     'OBRAS,INSTAL.EQUIP.P/FUND.EDUCACIONAL DE JATAÍ',
#     31960,
#     32024,
#     (['4.4.90.52.00', '1.500,00'],)),
#    ('12.364.1239.2.061',
#     'MANUT.ATIV.FUN.EDUCACIONAL DE JATAÍ',
#     32056,
#     32109,
#     (['3.1.90.11.00', '3.000,00'],
#      ['3.3.90.14.00', '300,00'],
#      ['3.3.90.30.00', '2.000,00'],
#      ['3.3.90.33.00', '950,00'],
#      ['3.3.90.34.00', '33.000,00'],
#      ['3.3.90.36.00', '1.000,00'],
#      ['3.3.90.39.00', '4.000,00'],
#      ['3.3.90.48.00', '50.000,00'],
#      ['3.3.90.92.00', '100,00'])),
#    ('12.364.2839.9.047',
#     'ENCARGOS ESPECIAIS DA FUND.EDUCACIONAL',
#     32314,
#     32370,
#     (['3.1.90.13.00', '6.000,00'],
#      ['3.1.90.94.00', '1.000,00'],
#      ['3.1.91.13.00', '1.000,00'],
#      ['3.2.90.22.00', '1.000,00'],
#      ['3.3.30.41.00', '82.619,07'],
#      ['3.3.90.18.00', '500,00'],
#      ['3.3.90.20.00', '500,00'],
#      ['3.3.90.32.00', '900,00'],
#      ['3.3.90.91.00', '500,00'],
#      ['3.3.90.93.00', '500,00'],
#      ['4.6.90.71.00', '5.000,00'],
#      ['4.6.91.71.00', '1.000,00']))]],
#  [('06', 'F.M.S. - JATAI'),
#   ('23', 'FUNDO MUNICIPAL DE SAUDE DE JATAI'),
#   [('10.122.1039.1.021',
#     'OBRAS,INSTAL.EQUIP.P/ SAÚDE EM GERAL',
#     33142,
#     33196,
#     (['4.4.90.51.00', '400.000,00'], ['4.4.90.52.00', '702.800,20'])),
#    ('10.122.1039.2.062',
#     'MANUT.DIR.GERAL DE PLANEJ.E GESTÃO ADM',
#     33258,
#     33314,
#     (['3.1.90.04.00', '300,00'],
#      ['3.1.90.11.00', '2.600.000,00'],
#      ['3.3.90.14.00', '225.000,00'],
#      ['3.3.90.30.00', '200.000,00'],
#      ['3.3.90.33.00', '5.000,00'],
#      ['3.3.90.34.00', '300.000,00'],
#      ['3.3.90.36.00', '80.000,00'],
#      ['3.3.90.39.00', '1.400.000,00'],
#      ['3.3.90.40.00', '150.000,00'],
#      ['3.3.90.92.00', '100,00'])),
#    ('10.122.1039.2.076',
#     'MANUTENÇÃO DO CONSELHO MUN. DE SAÚDE',
#     33561,
#     33615,
#     (['3.3.90.30.00', '4.000,00'],
#      ['3.3.90.36.00', '3.000,00'],
#      ['3.3.90.39.00', '2.000,00'])),
#    ('10.122.1039.2.086',
#     'MANUT. DE CONSÓRCIO INTERMUNICIPAL DE SAÚDE',
#     33691,
#     33752,
#     (['3.1.71.70.00', '4.000,00'],
#      ['3.3.71.70.00', '4.000,00'],
#      ['4.4.71.70.00', '4.000,00'])),
#    ('10.122.2839.9.048',
#     'ENCARGOS ESPECIAIS DA SAÚDE EM GERAL',
#     33829,
#     33883,
#     (['3.1.90.13.00', '6.800.000,00'],
#      ['3.1.90.91.00', '20.000,00'],
#      ['3.1.90.94.00', '50.000,00'],
#      ['3.1.91.13.00', '2.600.000,00'],
#      ['3.2.90.22.00', '215.000,00'],
#      ['3.3.50.43.00', '80.000,00'],
#      ['3.3.60.41.00', '500,00'],
#      ['3.3.90.10.00', '400,00'],
#      ['3.3.90.32.00', '5.000,00'],
#      ['3.3.90.46.00', '340.000,00'],
#      ['3.3.90.48.00', '500,00'],
#      ['3.3.90.49.00', '450.000,00'],
#      ['3.3.90.91.00', '150.000,00'],
#      ['3.3.91.97.00', '1.200.000,00'],
#      ['4.6.90.71.00', '10.000,00'],
#      ['4.6.91.71.00', '140.000,00'])),
#    ('10.301.1039.2.077',
#     'MANUTENÇÃO DO BLOCO DE ATENÇÃO BÁSICA',
#     34688,
#     34743,
#     (['3.1.90.04.00', '500,00'],
#      ['3.1.90.11.00', '7.600.000,00'],
#      ['3.3.90.30.00', '1.500.000,00'],
#      ['3.3.90.34.00', '7.000.000,00'],
#      ['3.3.90.36.00', '30.000,00'],
#      ['3.3.90.39.00', '600.000,00'],
#      ['3.3.90.92.00', '400,00'])),
#    ('10.302.1039.2.078',
#     'MANUTENÇÃO DO BLOCO MÉDIA E ALTA COMPLEXIDADE',
#     34923,
#     34986,
#     (['3.1.90.04.00', '400,00'],
#      ['3.1.90.11.00', '8.380.000,00'],
#      ['3.3.90.30.00', '4.200.000,00'],
#      ['3.3.90.34.00', '20.030.000,00'],
#      ['3.3.90.36.00', '10.000,00'],
#      ['3.3.90.39.00', '11.379.000,00'],
#      ['3.3.90.92.00', '474,34'])),
#    ('10.302.1039.2.088',
#     'MANUTENÇAO DA UNIDADE DE PRONTO ATENDIMENTO - UPA',
#     35170,
#     35237,
#     (['3.1.90.04.00', '400,00'],
#      ['3.1.90.11.00', '70.000,00'],
#      ['3.3.90.30.00', '40.000,00'],
#      ['3.3.90.34.00', '2.144,35'],
#      ['3.3.90.36.00', '5.000,00'],
#      ['3.3.90.39.00', '21.000,00'],
#      ['3.3.90.92.00', '300,00'])),
#    ('10.302.1039.2.089',
#     'MANUTENÇAO CENTRO DE ATENÇAO PSICOSSOCIAL - CAPS',
#     35833,
#     35899,
#     (['3.1.90.04.00', '400,00'],
#      ['3.1.90.11.00', '1.000.000,00'],
#      ['3.3.90.30.00', '300.000,00'],
#      ['3.3.90.34.00', '650.000,00'],
#      ['3.3.90.36.00', '40.000,00'],
#      ['3.3.90.39.00', '300.000,00'],
#      ['3.3.90.92.00', '500,00'])),
#    ('10.303.1039.2.079',
#     'MANUTENÇÃO DO BLOCO ASSISTÊNCIA FARMACÊUTICA',
#     36074,
#     36136,
#     (['3.3.90.30.00', '600.000,00'],
#      ['3.3.90.32.00', '40.000,00'],
#      ['3.3.90.36.00', '2.000,00'])),
#    ('10.304.1039.2.080',
#     'MANUTENÇÃO DO BLOCO DE VIGILÂNCIA SANITÁRIA',
#     36217,
#     36278,
#     (['3.1.90.04.00', '400,00'],
#      ['3.1.90.11.00', '1.200.000,00'],
#      ['3.3.90.30.00', '100.000,00'],
#      ['3.3.90.34.00', '3.000,00'],
#      ['3.3.90.36.00', '3.000,00'],
#      ['3.3.90.39.00', '20.000,00'],
#      ['3.3.90.92.00', '500,00'])),
#    ('10.305.1039.2.081',
#     'AÇÕES DE COMBATE A DENGUE DOENÇAS EPIDEMIOLÓGICAS',
#     36449,
#     36516,
#     (['3.1.90.04.00', '400,00'],
#      ['3.1.90.11.00', '1.600.000,00'],
#      ['3.3.90.30.00', '150.000,00'],
#      ['3.3.90.34.00', '180.000,00'],
#      ['3.3.90.36.00', '40.000,00'],
#      ['3.3.90.39.00', '50.000,00'],
#      ['3.3.90.92.00', '400,00']))]],
#  [('07', 'FUNDO MUNICIPAL DO MEIO AMBIENTE'),
#   ('18', 'FUNDO MUNICIPAL DO MEIO AMBIENTE'),
#   [('18.541.1839.1.022',
#     'OBRAS,INSTAL.EQUIP.FUN.MUN.MEIO AMBIENTE',
#     37638,
#     37696,
#     (['4.4.90.51.00', '155.769,34'], ['4.4.90.52.00', '18.973,59'])),
#    ('18.541.1839.2.063',
#     'MANUT.ATIV.DO FUNDO MUN.MEIO AMBIENTE',
#     37755,
#     37810,
#     (['3.1.90.04.00', '300,00'],
#      ['3.1.90.11.00', '10.000,00'],
#      ['3.3.90.14.00', '2.000,00'],
#      ['3.3.90.30.00', '40.000,00'],
#      ['3.3.90.34.00', '2.000,00'],
#      ['3.3.90.36.00', '20.000,00'],
#      ['3.3.90.39.00', '30.000,00'],
#      ['3.3.90.92.00', '100,00'])),
#    ('18.541.2839.9.049',
#     'ENCARGOS ESPECIAIS DO FUNDO DO MEIO AMBIENTE',
#     37998,
#     38060,
#     (['3.1.90.13.00', '3.000,00'],
#      ['3.1.90.94.00', '1.000,00'],
#      ['3.1.91.13.00', '1.000,00'],
#      ['3.3.50.43.00', '1.000,00'],
#      ['3.3.90.32.00', '1.000,00'],
#      ['4.6.90.71.00', '500,00']))]],
#  [('08', 'JATAIPREV - JATAI'),
#   ('19', 'JATAIPREV'),
#   [('09.272.0939.1.023',
#     'OBRAS,INSTAL.EQUIP. P/ JATAIPREV',
#     38690,
#     38740,
#     (['4.4.90.51.00', '78.460,39'], ['4.4.90.52.00', '47.433,98'])),
#    ('09.272.0939.2.064',
#     'ENC.C/PREV.SOCIAL E SEGURIDADE MUNICIPAL',
#     38798,
#     38856,
#     (['3.1.90.11.00', '250.000,00'],
#      ['3.3.90.14.00', '2.000,00'],
#      ['3.3.90.30.00', '25.000,00'],
#      ['3.3.90.34.00', '110.000,00'],
#      ['3.3.90.36.00', '50.000,00'],
#      ['3.3.90.39.00', '500.000,00'],
#      ['3.3.90.40.00', '40.000,00'],
#      ['3.3.90.47.00', '300.000,00'],
#      ['3.3.90.92.00', '100,00'])),
#    ('09.272.2839.9.050',
#     'ENCARGOS ESPECIAIS DO JATAIPREV',
#     39077,
#     39126,
#     (['3.1.90.01.00', '26.700.000,00'],
#      ['3.1.90.03.00', '3.000.000,00'],
#      ['3.1.90.05.00', '800.000,00'],
#      ['3.1.90.08.00', '500,00'],
#      ['3.1.90.09.00', '40.000,00'],
#      ['3.1.90.13.00', '40.000,00'],
#      ['3.1.90.91.00', '30.000,00'],
#      ['3.1.91.13.00', '20.000,00'],
#      ['3.2.90.22.00', '100,00'],
#      ['3.3.90.91.00', '30.000,00'],
#      ['3.3.90.93.00', '1.000,00']))]],
#  [('08', 'JATAIPREV - JATAI'),
#   ('99', 'RESERVA TÉCNICA DO RPPS'),
#   [('99.999.7999.7.999',
#     'RESERVA TÉCNICA DO RPPS',
#     39815,
#     39856,
#     (['7.7.99.99.99', '385.138,52'],))]],
#  [('09', 'FEMBOM - JATAI'),
#   ('20', 'FUNDO MUNICIPAL ESPECIAL CORPO DE BOMBEIROS'),
#   [('06.182.0439.1.024',
#     'OBRAS,INSTAL.EQUIP. P/O FEMBOM',
#     40392,
#     40440,
#     (['4.4.90.51.00', '57.204,11'], ['4.4.90.52.00', '47.433,98'])),
#    ('06.182.0439.2.065',
#     'MANUTENÇÃO DAS ATIVIDADES DO FEMBOM',
#     40498,
#     40551,
#     (['3.1.90.11.00', '41.362,42'],
#      ['3.1.90.34.00', '948,68'],
#      ['3.3.90.14.00', '19.256,93'],
#      ['3.3.90.30.00', '133.381,81'],
#      ['3.3.90.34.00', '28.460,39'],
#      ['3.3.90.36.00', '9.486,80'],
#      ['3.3.90.39.00', '176.152,59'],
#      ['3.3.90.40.00', '15.000,00'],
#      ['3.3.90.92.00', '94,87'])),
#    ('06.182.2839.9.051',
#     'ENCARGOS ESPECIAIS DO FEMBOM',
#     40764,
#     40810,
#     (['3.1.90.13.00', '4.743,40'],
#      ['3.3.50.43.00', '948,68'],
#      ['3.3.90.32.00', '1.138,42']))]],
#  [('10', 'FUNDO MUN. DIR. DA CRIANCA E ADOLESCENTE'),
#   ('01', 'FUNDO MUN. DOS DIREITOS DA CRIANÇA E DO ADOLESCENTE'),
#   [('08.243.0839.1.038',
#     'OBRAS,INSTAL.EQUIP.P/F.M.D.C.ADOLESCENTE',
#     41432,
#     41490,
#     (['4.4.90.52.00', '1.000,00'],)),
#    ('08.243.0839.2.073',
#     'ENC.C/FUNDO MUN.DIR.CRIANÇA/ADOLESCENTE',
#     41522,
#     41579,
#     (['3.3.90.30.00', '2.000,00'],
#      ['3.3.90.33.00', '500,00'],
#      ['3.3.90.36.00', '3.000,00'],
#      ['3.3.90.39.00', '5.000,00'],
#      ['3.3.90.92.00', '100,00'])),
#    ('28.845.2839.9.035',
#     'TRANSF.A INSTITUIÇÕES PRIVADAS P/APOIO AO FMDCA',
#     41696,
#     41761,
#     (['3.3.50.43.00', '85.000,00'],)),
#    ('28.846.2839.9.036',
#     'DOAÇÃO DE MATERIAIS P/APOIO AS ATIV.FMDCA',
#     41795,
#     41854,
#     (['3.3.90.32.00', '1.000,00'],))]],
#  [('11', 'FUNDO MUNICIPAL DE CIENCIA E TECNOLOGIA'),
#   ('25', 'FUNDO MUNICIPAL DE CIENCIA E TECNOLOGIA'),
#   [('19.573.1839.2.066',
#     'MANUT.ATIV.FUNDO MUN.CIÊNCIA E TECNOLOGIA',
#     42453,
#     42512,
#     (['3.1.90.04.00', '948,68'],
#      ['3.1.90.11.00', '4.743,40'],
#      ['3.1.90.16.00', '474,34'],
#      ['3.1.90.34.00', '948,68'],
#      ['3.1.90.92.00', '474,34'],
#      ['3.3.90.14.00', '1.897,36'],
#      ['3.3.90.30.00', '4.743,40'],
#      ['3.3.90.34.00', '948,68'],
#      ['3.3.90.36.00', '4.743,40'],
#      ['3.3.90.39.00', '4.743,40'],
#      ['3.3.90.92.00', '474,34'])),
#    ('19.573.2839.9.052',
#     'ENCARGOS ESPECIAIS DO FDO. C.E TECNOLOGIA',
#     42753,
#     42812,
#     (['3.1.90.13.00', '474,34'],
#      ['3.1.90.92.00', '237,17'],
#      ['3.1.90.94.00', '474,34'],
#      ['3.1.91.13.00', '948,68'],
#      ['3.1.91.92.00', '237,17'],
#      ['3.3.50.43.00', '1.423,02'],
#      ['3.3.90.20.00', '6.735,62'],
#      ['3.3.90.32.00', '474,34']))]],
#  [('13', 'FUNDO MUN. DE DEFESA DO CONSUMIDOR'),
#   ('27', 'FUNDO MUL. DE DEFESA DO CONSUMIDOR'),
#   [('04.422.0439.1.042',
#     'BENS MÓVEIS P/FDO.DE DEFESA DO CONSUMIDOR',
#     43531,
#     43590,
#     (['4.4.90.52.00', '20.000,00'],)),
#    ('04.422.0439.2.067',
#     'MANUT.ATIV.FUNDO MUN.DEFESA DO CONSUMIDOR',
#     43624,
#     43683,
#     (['3.1.90.11.00', '1.000,00'],
#      ['3.3.90.14.00', '1.000,00'],
#      ['3.3.90.30.00', '20.000,00'],
#      ['3.3.90.34.00', '1.500,00'],
#      ['3.3.90.36.00', '1.500,00'],
#      ['3.3.90.39.00', '30.000,00'],
#      ['3.3.90.92.00', '100,00'])),
#    ('04.422.2839.9.053',
#     'ENCARGOS ESP.DO FDO.DEFESA CONSUMIDOR',
#     43848,
#     43903,
#     (['3.1.90.13.00', '500,00'],
#      ['3.1.90.94.00', '500,00'],
#      ['3.1.91.13.00', '500,00'],
#      ['3.3.90.32.00', '500,00']))]],
#  [('14', 'FUNDO MUN. DE ASSISTENCIA SOCIAL'),
#   ('28', 'FUNDO MUNICIPAL DE ASSISTENCIA SOCIAL'),
#   [('08.122.0839.1.026',
#     'OBRAS,INSTAL.EQUIP.FUNDO MUN.ASSIST.SOCIAL',
#     44528,
#     44588,
#     (['4.4.90.51.00', '37.655,72'], ['4.4.90.52.00', '57.696,70'])),
#    ('08.122.0839.2.068',
#     'MANUT.DIVISÃO PROM.ASSISTÊNCIA SOCIAL',
#     44645,
#     44700,
#     (['3.1.90.04.00', '500,00'],
#      ['3.1.90.11.00', '500,00'],
#      ['3.3.90.14.00', '6.000,00'],
#      ['3.3.90.30.00', '100.000,00'],
#      ['3.3.90.33.00', '4.000,00'],
#      ['3.3.90.34.00', '85.000,00'],
#      ['3.3.90.36.00', '3.500,00'],
#      ['3.3.90.39.00', '25.000,00'],
#      ['3.3.90.92.00', '100,00'])),
#    ('08.122.0839.2.069',
#     'MANUT.DEPART.DE PROGRAMAS E PROJETOS',
#     44908,
#     44962,
#     (['3.3.90.30.00', '500,00'],
#      ['3.3.90.36.00', '1.000,00'],
#      ['3.3.90.39.00', '2.000,00'])),
#    ('08.122.2839.9.054',
#     'ENCARGOS ESPECIAIS DA ASSIST.SOCIAL GERAL',
#     45036,
#     45095,
#     (['3.1.90.13.00', '2.000,00'],
#      ['3.1.90.94.00', '1.000,00'],
#      ['3.1.91.13.00', '1.000,00'],
#      ['3.3.50.43.00', '46.000,00'],
#      ['3.3.90.32.00', '150.000,00'],
#      ['3.3.90.48.00', '1.000,00'],
#      ['3.3.90.91.00', '500,00'],
#      ['3.3.90.93.00', '500,00'],
#      ['3.3.91.47.00', '500,00'])),
#    ('08.241.0839.2.090',
#     'MANUTENÇÃO DO FUNDO MUNICIPAL DO IDOSO',
#     45302,
#     45358,
#     (['3.3.50.43.00', '54.000,00'],
#      ['3.3.90.30.00', '20.000,00'],
#      ['3.3.90.39.00', '1.000,00'])),
#    ('08.244.0839.2.083',
#     'BLOCO P.S.E(PAEFI,MSE,PACI,CREAS,IDOSO,PTMC,ETC)',
#     45879,
#     45945,
#     (['3.1.90.04.00', '400,00'],
#      ['3.1.90.11.00', '1.000,00'],
#      ['3.3.90.30.00', '270.000,00'],
#      ['3.3.90.32.00', '5.000,00'],
#      ['3.3.90.36.00', '3.000,00'],
#      ['3.3.90.39.00', '130.000,00'],
#      ['3.3.90.92.00', '100,00'])),
#    ('08.244.0839.2.084',
#     'BLOCO P.S.B (SCFV,PBF,CRAS,PBV III E OUTROS)',
#     46111,
#     46173,
#     (['3.1.90.04.00', '1.000,00'],
#      ['3.1.90.11.00', '3.500,00'],
#      ['3.3.90.30.00', '352.500,00'],
#      ['3.3.90.36.00', '4.000,00'],
#      ['3.3.90.39.00', '36.000,00'],
#      ['3.3.90.92.00', '100,00'])),
#    ('08.244.0839.2.085',
#     'BOLSA FAMÍLIA (IGD SUAS, IGDBF E OUTROS)',
#     46318,
#     46376,
#     (['3.1.90.04.00', '500,00'],
#      ['3.1.90.11.00', '1.000,00'],
#      ['3.3.90.30.00', '80.000,00'],
#      ['3.3.90.32.00', '3.000,00'],
#      ['3.3.90.36.00', '5.000,00'],
#      ['3.3.90.39.00', '30.000,00'],
#      ['3.3.90.92.00', '100,00'])),
#    ('16.482.0839.1.027',
#     'CONSTR.REFORMA E AMPL.DE MORADIAS',
#     46540,
#     46591,
#     (['4.4.90.51.00', '10.000,00'], ['4.4.90.52.00', '2.000,00'])),
#    ('16.482.2839.9.057',
#     'DOAÇÃO MATERIAIS P/CONST.REF.AMP.MORADIA',
#     46647,
#     46705,
#     (['3.3.90.32.00', '4.000,00'],))]],
#  [('15', 'FUNDO MUNICIPAL DE TRANSITO'),
#   ('29', 'FUNDO MUNICIPAL DE TRANSITO'),
#   [('26.122.1539.1.028',
#     'OBRAS,INSTAL.EQUIP.P/FUNDO MUN.TRÂNSITO',
#     47667,
#     47724,
#     (['4.4.90.51.00', '18.123,59'], ['4.4.90.52.00', '94.867,96'])),
#    ('26.122.1539.2.070',
#     'MANUT.ATIVIDADES DE FUNDO MUN.DE TRÂNSITO',
#     47782,
#     47841,
#     (['3.1.90.11.00', '3.000,00'],
#      ['3.3.90.14.00', '3.000,00'],
#      ['3.3.90.30.00', '220.000,00'],
#      ['3.3.90.34.00', '4.000,00'],
#      ['3.3.90.36.00', '12.000,00'],
#      ['3.3.90.39.00', '300.000,00'],
#      ['3.3.90.92.00', '100,00'])),
#    ('26.122.2839.9.058',
#     'ENCARGOS ESPECIAIS DO FUNDO DE TRÂNSITO',
#     48010,
#     48067,
#     (['3.1.90.13.00', '4.000,00'],
#      ['3.1.90.94.00', '500,00'],
#      ['3.1.91.13.00', '4.000,00'],
#      ['3.3.90.32.00', '1.000,00'],
#      ['3.3.90.93.00', '5.000,00']))]],
#  [('17', 'FEPJPEM - JATAÍ'),
#   ('30', 'FUNDO ESP DOS PROCURADORES JURIDICOS PODER EXECUTIVO'),
#   [('04.122.0439.1.043',
#     'EQUIPAMENTOS PARA FDO PROCURADORES',
#     48707,
#     48759,
#     (['4.4.90.52.00', '2.000,00'],)),
#    ('04.122.0439.2.087',
#     'MATENÇÃO DAS ATIV. DO FDO. PROCURADORES',
#     48791,
#     48848,
#     (['3.3.90.14.00', '1.000,00'],
#      ['3.3.90.30.00', '4.000,00'],
#      ['3.3.90.36.00', '176.182,45'],
#      ['3.3.90.39.00', '2.000,00']))]]]

# %% [markdown]
# # Funções e Subfunções

# %%
with open(f'funcao.txt', 'r') as fnd:
    funcoes = fnd.read()
    funcoes = re.split(r'\||\n', funcoes)
    funcoes = [(funcoes[i], funcoes[i+1]) for i in range(0, len(funcoes)-1, 2)]
    for c, e in funcoes:
        created, f = models.Funcao.objects.get_or_create(loa=loa, codigo=c, especificacao=e)
funcoes = sorted(funcoes, key=lambda x: (x[0], x[1]))
models.SubFuncao.objects.filter(loa=loa).count()
# Out:
# 0

# %%
with open(f'subfuncao.txt', 'r') as fnd:
    subfs = fnd.read()
    subfs = re.split(r'\t|\n', subfs)
    subfs = [(subfs[i], subfs[i+1], subfs[i+2]) for i in range(0, len(subfs)-2, 3)]
    for fc, c, e in subfs:
        f = models.Funcao.objects.filter(loa=loa, codigo=fc).first()
        created, sf = models.SubFuncao.objects.get_or_create(loa=loa, funcao=f, codigo=c, especificacao=e)
subfs = sorted(subfs, key=lambda x: (x[0], x[1]))
models.SubFuncao.objects.filter(loa=loa).count()
# Out:
# 114

# %%
count = [0,0,0]
for orgao, unidade, despesas in unidades:
    count[0] += 1
    for desp, espec, x1, x2, naturezas in despesas:
        count[1] += 1
        for nat in naturezas:
            count[2] += 1
print(count)
# Out:
# [28, 164, 749]

# %%
count = 0
for orgao, unidade, despesas in unidades:
    o_obj, created = models.Orgao.objects.get_or_create(
        loa=loa, codigo=orgao[0], especificacao=orgao[1]
    )

    uo_obj, created = models.UnidadeOrcamentaria.objects.get_or_create(
        loa=loa, orgao=o_obj, codigo=unidade[0], especificacao=unidade[1]
    )
    
    for desp, espec, x1, x2, naturezas in despesas:
        desp_re = re.match(r'(?P<funcao>\d{2})\.(?P<subfuncao>\d{3})'
                           r'\.(?P<programa>\d{4})\.(?P<acao>\d\.\d{3})', desp)

        funcao_obj = models.Funcao.objects.filter(loa=loa, codigo=desp_re['funcao']).first()
        subfunc_obj = models.SubFuncao.objects.filter(loa=loa, codigo=desp_re['subfuncao']).first()
        
        programa_obj, created = models.Programa.objects.get_or_create(loa=loa, codigo=desp_re['programa'])
        
        acao_obj, created = models.Acao.objects.get_or_create(loa=loa, codigo=desp_re['acao'], especificacao=espec)
        
        for nat in naturezas:
            count += 1
            natureza, created = models.Natureza.objects.get_or_create(loa=loa, codigo=nat[0])
            
            desp_obj, created = models.Despesa.objects.get_or_create(
                loa = loa,
                orgao = o_obj,
                unidade = uo_obj,
                funcao = funcao_obj,
                subfuncao = subfunc_obj,
                programa = programa_obj,
                acao = acao_obj,
                natureza = natureza)
            
            desp_obj.valor_materia = Decimal(nat[1].replace('.', '').replace(',', '.'))
            
            try: 
                desp_obj.save()
            except Exception as e:
                print(e)
                break
        if not desp_obj.pk:
            break
print(count, models.Despesa.objects.filter(loa=loa).count())
# Out:
# 749 749

# %%
a = """text_global = load_pages_with(page_mask='ADENDO III A PORTARIA SOF N.15 DE 20/06/78')
naturezas = []
for m in re.finditer(r'\n?(\d{1,2}\.\d{1,2}\.\d{2}\.\d{2}\.\d{2})\n([^0-9]*)?\n?', text_global):
    naturezas.append(m.groups())
naturezas = sorted(naturezas, key=lambda x: x[0])
for esp, cod in naturezas:
    nat, created = models.Natureza.objects.get_or_create(loa=loa, codigo=cod)
    nat.especificacao=esp
    nat.save()
    """

# %% [markdown]
# # Natureza da Despesa

# %%
text_global = load_pages_with(page_mask='ADENDO III A PORTARIA SOF N.08 DE 04/02/85')
naturezas = []
for m in re.finditer(r'\n(\d{1,2}\.\d{1,2}\.\d{2}\.\d{2}\.\d{2})\n(.*)\n', text_global):
    naturezas.append(m.groups())
naturezas = sorted(naturezas, key=lambda x: x[0])

# %%
for cod, esp in naturezas:
    nat, created = models.Natureza.objects.get_or_create(loa=loa, codigo=cod)
    nat.especificacao=esp
    nat.save()

# %%
with open(f'2024_natureza_despesa.txt', 'r') as fnd:
    lines = fnd.read()
    lines = re.split(r'\t|\n', lines)
    naturezas = [(lines[i], lines[i+1]) for i in range(0, len(lines)-1, 2)] 
    for cod, esp in naturezas:
        nat, created = models.Natureza.objects.get_or_create(loa=loa, codigo=cod)
        if not nat.especificacao:
            nat.especificacao=esp
            nat.save()

# %% [markdown]
# # Programas

# %%
text_global = load_pages_with(page_mask='ADENDO V A PORTARIA SOF N.15 DE 20/06/78')

# %%
programas = set()
for m in re.finditer(r'\n(\d{4})\n(.+)\n', text_global):
    programas.add(m.groups())

# %%
len(programas), models.Programa.objects.filter(loa=loa).values_list('codigo', flat=True).count()
# Out:
# (0, 22)

# %%
for cod, esp in list(programas):
    prog, created = models.Programa.objects.get_or_create(loa=loa, codigo=cod)
    prog.especificacao=esp
    prog.save()
